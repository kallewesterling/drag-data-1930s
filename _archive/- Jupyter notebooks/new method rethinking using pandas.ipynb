# %%
Note: This notebook now lives here:
    
    
https://colab.research.google.com/drive/1Id07FmLqLDLwDmThXrX45VCDsDmgj-tO

# %%
import pandas as pd
import re
from IPython.display import Markdown, display
from collections import Counter
import networkx as nx
from networkx.algorithms import community
from datetime import timedelta
import datetime

SETTINGS = {
    'DELTA': timedelta(days=14), # sets the standard for the periodizing of dates as belonging together
    'MIN_DATE': datetime.datetime.strptime('1920', '%Y'),
    'MAX_DATE': datetime.datetime.strptime('1950', '%Y'),
}

GRAPH_SETTINGS = {
    'FILTER_NODES': [
        'unknown',
        'unnamed'
    ]
}

    
def group_dates(dates:list=[], delta:datetime.timedelta=SETTINGS['DELTA'], dateformat='%Y-%m-%d'):
    """https://gist.github.com/kallewesterling/9a8d12ce073776ed52865bfb362ad073"""

    try:
        dates = sorted([datetime.datetime.strptime(x, dateformat) for x in dates])
    except ValueError as e:
        date = re.search(r'''['"](.*)['"] does not match format''', str(e))
        if date:
            date = date.groups()[0]
        raise ValueError(f'A date found in list that did not adhere to format (`{date}`). Needs to follow format `{dateformat}`.') from None

    if isinstance(delta, int):
        delta = timedelta(days=delta)

    periods = []

    for ix, date in enumerate(dates):
        min_date = date - delta
        max_date = date + delta

        prev_date, next_date = None, None
        start_chain, end_chain, in_chain, solo_date = None, None, None, None
        prev_date_in_range, next_date_in_range = None, None

        try:
            if ix-1 >= 0:
                prev_date = dates[ix-1]
        except IndexError:
            prev_date = None

        try:
            next_date = dates[ix+1]
        except IndexError:
            next_date = None

        if next_date:
            next_date_in_range = next_date >= min_date and next_date <= max_date

        if prev_date:
            prev_date_in_range = prev_date >= min_date and prev_date <= max_date

        if all([next_date, prev_date, prev_date_in_range, next_date_in_range]):
            # In the loop and in a chain (near previous date and next)
            in_chain = True
        elif all([next_date, prev_date, next_date_in_range]) and not prev_date_in_range:
            # In the loop and beginning of a chain (not near previous date but near next)
            start_chain = True
        elif all([next_date, prev_date, prev_date_in_range]) and not next_date_in_range:
            # In the loop and end of a chain (near previous date but not next)
            end_chain = True
        elif all([next_date, prev_date]) and not all([prev_date_in_range, next_date_in_range]):
            # In the loop but solo date (not not near previous date nor next)
            solo_date = True
        elif next_date and next_date_in_range:
            # In the loop but solo date (not not near previous date nor next)
            start_chain = True
        elif next_date:
            solo_date = True
        elif prev_date and prev_date_in_range:
            end_chain = True
        elif prev_date:
            solo_date = True
        elif not next_date and not prev_date:
            solo_date = True
        else:
            raise RuntimeError('An unexpected error occurred.')

        if start_chain:
            periods.append([date])

        elif end_chain:
            periods[len(periods)-1].append(date)

        elif solo_date:
            periods.append([date])

        elif in_chain:
            periods[len(periods)-1].append(date)
            
    return periods


# Data clean up functions
def has_required_data(row):
    '''(internal) for use with DataFrame lambda function to ensure that any given row has the required data present'''
    has_performer = row['Performer'] != '' or row['Normalized performer'] != '' or (row['Performer first-name'] != '' or row['Performer last-name']) != ''
    # has_city = row['City'] or row['Normalized City']
    has_venue = row['Venue'] != ''
    if has_performer and has_venue:
        return True
    else:
        return False


def has_correct_date(row):
    '''(internal) for use with DataFrame lambda function to ensure that any given row has a correct date present'''
    return re.search(r'\d{4}\-\d{2}\-\d{2}', row['Date']) != None


def get_performer(row, null_value=''):
    '''(internal) for use with DataFrame lambda function to return the cleaned-up version of a performer's name (in an order of priority)'''

    if row['Performer first-name'] and row['Performer last-name']:
        return row['Performer first-name'] + ' ' + row['Performer last-name']
    
    for r in ['Normalized performer', 'Performer']:
        if row[r]:
            return row[r]
    
    return null_value

    
def get_city(row, null_value=''):
    '''(internal) for use with DataFrame lambda function to return the cleaned-up version of a city's name (in an order of priority)'''
    for r in ['Normalized City', 'City']:
        if row[r]:
            return row[r]
    
    return null_value


def get_unique_venue(row, null_value=''):
    '''(internal) for use with DataFrame lambda function to return the cleaned-up version of a venue's name (in an order of priority)'''
    if row['Venue'] and row['City']:
        return row['Venue'] + ' (' + row['City'] + ')'
    
    for r in ['Venue', 'City']:
        if row[r]:
            return row[r]

    return null_value


def get_source(row, null_value=''):
    '''(internal) for use with DataFrame lambda function to return the cleaned-up version of a source (in an order of priority)'''
    for r in ['Source clean', 'Source']:
        if row[r]:
            return row[r]

    return null_value


def get_revue(row, null_value=''):
    '''(internal) for use with DataFrame lambda function to return the cleaned-up version of a revue's name (in an order of priority)'''
    for r in ['Normalized Revue Name', 'Revue name']:
        if row[r]:
            return row[r]
    
    return null_value

# %%
df = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vT0E0Y7txIa2pfBuusA1cd8X5OVhQ_D0qZC8D40KhTU3xB7McsPR2kuB7GH6ncmNT3nfjEYGbscOPp0/pub?gid=0&single=true&output=csv')

# Fix basic stuff
df.replace('—', '', inplace=True)
df.replace('–', '', inplace=True)
df.fillna('', inplace=True)

Markdown(f'**{df.shape[0]} rows imported.**')
# Out:
# **8001 rows imported.**

# %%
# Check for required data
df['has_required_data'] = df.apply(lambda row: has_required_data(row), axis=1)
df.drop(df[df['has_required_data'] == False].index, inplace=True)
Markdown(f'**{df.shape[0]} rows after filtering**: Required data.')

df.sort_values('Normalized performer').head()
# Out:
#             Date Category Performer Normalized performer Performer first-name  \
# 1939  1956-07-07                             Adrian Ames               Adrian
# 1876  1952-11-07                             Adrian Ames               Adrian
# 1875  1952-11-04                             Adrian Ames               Adrian
# 1874  1952-10-31                             Adrian Ames               Adrian
# 1873  1952-10-30                             Adrian Ames               Adrian
#
#      Performer last-name            Venue           City Normalized City  \
# 1939                Ames   Forbidden City  Honolulu, HI?    Honolulu, HI
# 1876                Ames  Falcon Show Bar
# 1875                Ames  Falcon Show Bar
# 1874                Ames  Falcon Show Bar
# 1873                Ames  Falcon Show Bar
#
#      Revue name  ... Comment on node: venue Comment on node: city  \
# 1939             ...
# 1876             ...
# 1875             ...
# 1874             ...
# 1873             ...
#
#      Comment on edge: revue Blackface Sepia Fan dancer/Sally Rand  \
# 1939
# 1876
# 1875
# 1874
# 1873
#
#      Exotic/erotic/oriental dancer/Gypsy Has image Address has_required_data
# 1939                                                                    True
# 1876                                                                    True
# 1875                                                                    True
# 1874                                                                    True
# 1873                                                                    True
#
# [5 rows x 35 columns]

# %%
# Filter
df.drop(df[df['Exclude from visualization'] == True].index, inplace=True)
Markdown(f'**{df.shape[0]} rows after filtering**: Exclusion from visulization.')
# Out:
# **5994 rows after filtering**: Exclusion from visulization.

# %%
# Filter
df.drop(df[df['Unsure whether drag artist'] == 'TRUE'].index, inplace=True)
Markdown(f'**{df.shape[0]} rows after filtering**: Unsure whether drag artist.')
# Out:
# **7497 rows after filtering**: Unsure whether drag artist.

# %%
df['has_correct_date'] = df.apply(lambda row: has_correct_date(row), axis=1)
df.drop(df[df['has_correct_date'] == False].index, inplace=True)
Markdown(f'**{df.shape[0]} rows after filtering**: Full date in `Date` column.')
# Out:
# **5460 rows after filtering**: Full date in `Date` column.

# %%
def string_date(row):
    return row['Date'].strftime('%Y-%m-%d')

if SETTINGS.get('MIN_DATE') or SETTINGS.get('MAX_DATE'):
    df['Date'] = pd.to_datetime(df['Date'])
    df = df[(df['Date'] > SETTINGS.get('MIN_DATE')) & (df['Date'] < SETTINGS.get('MAX_DATE'))]
    df['Date'] = df.apply(lambda row: string_date(row), axis=1)
    display(Markdown(f'**{df.shape[0]} rows after filtering**: Min and max date set.'))
# Out:
# **4881 rows after filtering**: Min and max date set.

# %%
# Clean up names
df['Performer'] = df.apply(lambda row: get_performer(row), axis=1)
df['City'] = df.apply(lambda row: get_city(row), axis=1)
df['Source'] = df.apply(lambda row: get_source(row), axis=1)
df['Revue'] = df.apply(lambda row: get_revue(row), axis=1)
df['Unique venue'] = df.apply(lambda row: get_unique_venue(row), axis=1)
Markdown(f'**Cleaned up all names**.')
# Out:
# **Cleaned up all names**.

# %%
# TODO: redo this part + include comment on node parts
# Drop *node* information - i.e. not relevant for edges

node_information = {}
node = {
    'Legal name': None,
    'Alleged age': None,
    'Assumed birth year': None,
    'Source': None
}
for ix, row in df.iterrows():
    if row['Legal name'] or row['Alleged age'] or row['Assumed birth year']:
        if row['Performer'] not in node_information:
            node_information[row['Performer']] = []
        
        d = node
        for cat in ['Legal name', 'Assumed birth year', 'Alleged age', 'Source']:
            d[cat] = row[cat]
            
        node_information[row['Performer']].append(d)

Markdown(f'**Extracted node information**.')
# Out:
# **Extracted node information**.

# %%
# Drop unnecessary information
cols = ['EIMA', 'Imported from former archive', 'Search (newspapers.com)', 'Search (fulton)', 'Venue', 'City', 'Revue name', 'Normalized Revue Name', 'Legal name', 'Alleged age', 'Assumed birth year', 'Source clean', 'Category', '2020-12-31 ID', 'Normalized City', 'Performer first-name', 'Performer last-name', 'Normalized performer', 'has_required_data', 'has_correct_date', 'Exclude from visualization', 'Unsure whether drag artist']
for col in cols:
    try:
        del df[col]
    except KeyError:
        pass # already gone

df = df.rename(columns={'Unique venue': 'Venue'})

Markdown(f'**Fixed columns**: Renamed some columns and removed all unneccesary columns:' + '\n - ' + '\n -'.join(cols))
# Out:
# **Fixed columns**: Renamed some columns and removed all unneccesary columns:
#  - EIMA
#  -Imported from former archive
#  -Search (newspapers.com)
#  -Search (fulton)
#  -Venue
#  -City
#  -Revue name
#  -Normalized Revue Name
#  -Legal name
#  -Alleged age
#  -Assumed birth year
#  -Source clean
#  -Category
#  -2020-12-31 ID
#  -Normalized City
#  -Performer first-name
#  -Performer last-name
#  -Normalized performer
#  -has_required_data
#  -has_correct_date
#  -Exclude from visualization
#  -Unsure whether drag artist

# %%
df = df.reset_index(drop=True)
Markdown(f'**Index has been reset**.')
# Out:
# **Index has been reset**.

# %%
df_venues = pd.DataFrame()

for venue, data in df.groupby(['Venue']):
    all_dates = [x for x in data['Date']]
    grouped_dates = group_dates(all_dates)
    grouped_dates_count = len(group_dates(all_dates))
    s = pd.Series({
        'Number of datapoints': len(data),
        'All dates': list(set(all_dates)),
        'Grouped dates': grouped_dates,
        'Number of grouped dates': grouped_dates_count,
        'First date in dataset': min([pd.to_datetime(x) for x in all_dates]),
        'Last date in dataset': max([pd.to_datetime(x) for x in all_dates])
    }, name=venue)
    df_venues = df_venues.append(s)

df_venues['Number of datapoints'] = df_venues['Number of datapoints'].apply(lambda x: int(x))
df_venues['Number of grouped dates'] = df_venues['Number of grouped dates'].apply(lambda x: int(x))

display(Markdown(f'**Grouped information about appearances at clubs**: In a separate dataframe (`df_venues`).'))
df_venues.sort_values('Number of grouped dates', ascending=False).head(5)
# Out:
# **Grouped information about appearances at clubs**: In a separate dataframe (`df_venues`).
#                                                                          All dates  \
# Club Richman (New York, NY)      [1935-01-03, 1934-07-12, 1936-02-15, 1934-01-2...
# Cabin Inn (Chicago, IL)          [1939-09-09, 1937-03-13, 1936-09-12, 1938-08-2...
# Finocchio's (San Francisco, CA)  [1941-05-23, 1942-01-30, 1945-03-01, 1946-08-2...
# Club Frontenac (Detroit, MI)     [1937-03-13, 1941-12-16, 1937-04-24, 1937-02-1...
# Joe’s Deluxe (Chicago, IL)       [1943-03-27, 1945-08-04, 1947-12-20, 1948-04-0...
#
#                                 First date in dataset  \
# Club Richman (New York, NY)                1931-12-13
# Cabin Inn (Chicago, IL)                    1935-09-21
# Finocchio's (San Francisco, CA)            1938-12-22
# Club Frontenac (Detroit, MI)               1937-01-09
# Joe’s Deluxe (Chicago, IL)                 1935-12-07
#
#                                                                      Grouped dates  \
# Club Richman (New York, NY)      [[1931-12-13 00:00:00], [1932-02-06 00:00:00],...
# Cabin Inn (Chicago, IL)          [[1935-09-21 00:00:00], [1936-09-12 00:00:00],...
# Finocchio's (San Francisco, CA)  [[1938-12-22 00:00:00, 1938-12-22 00:00:00, 19...
# Club Frontenac (Detroit, MI)     [[1937-01-09 00:00:00, 1937-01-22 00:00:00, 19...
# Joe’s Deluxe (Chicago, IL)       [[1935-12-07 00:00:00], [1943-03-27 00:00:00, ...
#
#                                 Last date in dataset  Number of datapoints  \
# Club Richman (New York, NY)               1944-12-06                    94
# Cabin Inn (Chicago, IL)                   1939-10-28                    58
# Finocchio's (San Francisco, CA)           1947-01-18                    38
# Club Frontenac (Detroit, MI)              1942-06-04                   110
# Joe’s Deluxe (Chicago, IL)                1948-10-02                    40
#
#                                  Number of grouped dates
# Club Richman (New York, NY)                           24
# Cabin Inn (Chicago, IL)                               14
# Finocchio's (San Francisco, CA)                       13
# Club Frontenac (Detroit, MI)                          13
# Joe’s Deluxe (Chicago, IL)                            12

# %%
for venue, row in df_venues.iterrows():
    for period, date_list in enumerate(row['Grouped dates'], start=1):
        for date in date_list:
            df_ix = df[(df['Date'] == date.strftime('%Y-%m-%d')) & (df['Venue'] == venue)].index
            df.at[df_ix, 'Venue - Date grouping'] = period
            
display(Markdown(f'**Added date groupings to main dataframe**.'))
df.sort_values('Venue - Date grouping', ascending=False).head()
# Out:
# **Added date groupings to main dataframe**.
#             Date           Performer  \
# 4394  1944-12-06       Tex Hendricks
# 4229  1936-05-09  Satch and Satchell
# 2423  1936-05-09          Jack Mason
# 3353  1936-03-21       Lester Lamont
# 2421  1936-04-04          Jack Mason
#
#                                                  Source Edge Comment  \
# 4394  OBITUARIES, Variety, 156, no. 13, December 6, ...
# 4229  Club Richman Charged With Objectionable Show, ...
# 2423  Club Richman Charged With Objectionable Show, ...
# 3353    Route Department, The Billboard, March 21, 1936
# 2421  Route Department, The Billboard, April 4, 1936...
#
#      Quote from source Comment on node: performer Comment on node: venue  \
# 4394                     Appeared as "sepia dame"
# 4229
# 2423                                           MC
# 3353
# 2421
#
#      Comment on node: city Comment on edge: revue Blackface Sepia  \
# 4394                                                         True
# 4229
# 2423
# 3353
# 2421
#
#      Fan dancer/Sally Rand Exotic/erotic/oriental dancer/Gypsy Has image  \
# 4394
# 4229
# 2423
# 3353
# 2421
#
#      Address                             Revue                        Venue  \
# 4394                                            Club Richman (New York, NY)
# 4229                                            Club Richman (New York, NY)
# 2423                                            Club Richman (New York, NY)
# 3353                                            Club Richman (New York, NY)
# 2421          Jack Mason and His Playboy Revue  Club Richman (New York, NY)
#
#       Venue - Date grouping
# 4394                   24.0
# 4229                   23.0
# 2423                   23.0
# 3353                   22.0
# 2421                   22.0

# %%
############### SETUP NETWORK VISUALIZATION #############################################

# %%
G = nx.MultiGraph()

for groups, data in df.groupby(['Venue', 'Venue - Date grouping']):
    venue, period = groups
    performers = list(set(data['Performer']))
    in_date_grouping = len(data)
    dates = [pd.to_datetime(x) for x in data['Date']]
    min_date = min(dates).strftime('%Y-%m-%d')
    max_date = max(dates).strftime('%Y-%m-%d')
    if len(performers) > 1:
        for source in performers:
            for target in [x for x in performers if not x == source]:
                include = True
                
                for filtered_name in [x.lower() for x in GRAPH_SETTINGS['FILTER_NODES']]:
                    if filtered_name in source.lower() or filtered_name in target.lower():
                        include = False
                
                if include:
                    edge = (source, target, 0)
                    if edge in G.edges:
                        if not venue in G.edges[edge]['venues']:
                            G.edges[edge]['venues'].append(venue)
                    else:
                        G.add_edges_from([(source, target, 0, {'in_date_grouping': in_date_grouping, 'venues': [venue], 'min_date': min_date, 'max_date': max_date})])

display(Markdown('**Generated network graph**.'))
# Out:
# **Generated network graph**.

# %%
display(Markdown('**Setting up community information**: using the Girvan-Newman algorithm.'))
c = nx.community.girvan_newman(G)
first_girvan_newman_iteration = next(c)
girvan_newman_groups = {group: names for group, names in enumerate([list(x) for x in first_girvan_newman_iteration], start=1)}
# Out:
# **Setting up community information**: using the Girvan-Newman algorithm.

# %%
display(Markdown('**Setting up community information**: using the Clauset-Newman-Moore algorithm.'))
c = nx.community.greedy_modularity_communities(G)
clauset_newman_moore_groups = {group: names for group, names in enumerate([list(x) for x in c], start=1)}
# Out:
# **Setting up community information**: using the Clauset-Newman-Moore algorithm.

# %%
def get_modularity(row, groups):
    for group, names in groups.items():
        if row['Performer'] in names:
            return group
    
    return 0

df['Girvan Newman Modularity'] = df.apply(lambda row: get_modularity(row, girvan_newman_groups), axis=1)
df['Clauset-Newman-Moore Modularity'] = df.apply(lambda row: get_modularity(row, clauset_newman_moore_groups), axis=1)

display(Markdown('**Added community information to dataframe**.'))
# Out:
# **Added community information to dataframe**.

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
comment_replacer = {
    'm.c.': 'mc',
    'm. c.': 'mc',
    'credited as': ''
}

comment_skipper = [
    'name inferred from',
    'name corroborated by',
    'corroborates that',
    'unclear who was in drag',
    'corroborated'
]

keyword_searches = [
    'snake dancer',
    'fan dance',
    ''
]


def get_clean_comments(comments, comment_replacer, comment_skipper, keyword_searches):
    clean_comments = [x.lower() for x in comments]
    _clean_comments = []
    for ix, comment in enumerate(clean_comments):
        moveon = False
        for skip in comment_skipper:
            if skip in comment:
                moveon = True
        if moveon:
            continue

        if '; ' in comment:
            for comment in comment.split('; '):
                _clean_comments.append(comment)
        else:
            _clean_comments.append(comment)

    clean_comments = _clean_comments
            
    for a, b in comment_replacer.items():
        clean_comments = list(set([x.replace(a, b).strip() for x in clean_comments]))

    return clean_comments


def get_keywords(clean_comments, exclude):
    keywords = []
    for comment in clean_comments:
        quotes = re.findall(r'(?:"(.*?)")', comment)
        for quote in quotes:
            doc = nlp(quote)
            lst = [x for x in [token.lemma_ for token in doc if not token.is_quote and not token.is_punct and not token.is_stop] if not x in names]
            keywords.extend(lst)
    return keywords


for node in G.nodes:
    modularity = list(set([x for x in df[df['Performer'] == node]['Girvan Newman Modularity']]))
    if len(modularity) > 1:
        raise RuntimeError(f'A performer was found ({node}) that belonged to more than one Girvan-Newman group. It should not be possible.')
    G.nodes[node]['Girvan Newman Modularity'] = modularity[0]
    
    modularity = list(set([x for x in df[df['Performer'] == node]['Clauset-Newman-Moore Modularity']]))
    if len(modularity) > 1:
        raise RuntimeError(f'A performer was found ({node}) that belonged to more than one Clauset-Newman-Moore group. It should not be possible.')
    G.nodes[node]['Clauset-Newman-Moore Modularity'] = modularity[0]
    
    comments = list(set([x for x in df[df['Performer'] == node]['Comment on node: performer'] if x]))
    clean_comments = get_clean_comments(comments, comment_replacer, comment_skipper, keyword_searches)
    
    names = node.lower().split()
    keywords = get_keywords(clean_comments, names)
    
    if keywords:
        G.nodes[node]['Keywords'] = ', '.join(list(set(keywords)))
    else:
        G.nodes[node]['Keywords'] = ''

    G.nodes[node]['Comments'] = ', '.join(comments)

display(Markdown('**Added/adjusted node information in graph**.'))
# Out:
# **Added/adjusted node information in graph**.

# %%
for edge in G.edges:
    G.edges[edge]['weight'] = len(G.edges[edge]['venues']) # Adjust the weight to be reflecting the number of edges venues that the two nodes appeared in -- TODO: This might mean that we're doing/should do weighted edges
    G.edges[edge]['venues'] = ', '.join(G.edges[edge]['venues'])

display(Markdown('**Added/adjusted edge information in graph**.'))
# Out:
# **Added/adjusted edge information in graph**.

# %%
filename = 'graph'
if SETTINGS.get('MIN_DATE'):
    filename += '-' + str(SETTINGS.get('MIN_DATE').year)
if SETTINGS.get('MAX_DATE'):
    filename += '-' + str(SETTINGS.get('MAX_DATE').year)
filename += datetime.datetime.now().strftime(' (exported %Y-%m-%d)')
filename += '.gexf'

nx.write_gexf(G=G, path=filename)

display(Markdown(f'**File saved**: {filename}.'))
# Out:
# **File saved**: graph-1920-1950 (exported 2021-04-14).gexf.

# %%
df.sample(50)
# Out:
#             Date                               Performer  \
# 1985  1935-08-14                           Jean La Monte
# 2719  1936-12-11     Unnamed performer at The Paddock 14
# 1487  1935-05-17                           Jean Farrelly
# 3791  1940-05-11                          Nicki Gallucci
# 418   1933-08-08              Billy ("Senorita") Herrera
# 3955  1942-02-23                         Francis Russell
# 39    1925-11-29                              Bert Errol
# 3371  1939-02-12                            Patsy Keller
# 307   1932-09-27  Unnamed performer at B.B.B.'s cellar 9
# 2198  1935-11-30                          Sepia Mae West
# 460   1933-09-01                             Lena Rivers
# 1396  1935-04-05                            Frank Stroud
# 3008  1937-11-06                               Gene Dana
# 4436  1947-09-04              Billy ("Senorita") Herrera
# 3691  1940-02-03                          Johnny Mangrum
# 1322  1935-03-09                            George Kelly
# 4405  1947-06-12              Billy ("Senorita") Herrera
# 4115  1943-01-09              Billy ("Senorita") Herrera
# 4257  1947-03-18                                Del Raye
# 108   1927-11-20                            Karyl Norman
# 4363  1947-05-09                        Francis Stillman
# 4297  1947-04-28                             Vernon Hoff
# 1040  1934-12-22                              Babe Allen
# 4601  1948-08-22                                 Au Sing
# 691   1934-02-01                              Jack Mason
# 3907  1941-10-23                             Frank Doran
# 60    1926-04-17                                Dell Day
# 2437  1936-09-07    Unnamed performer at Italian Villa 8
# 21    1924-12-16                            Tom Martelle
# 186   1930-06-21                            Karyl Norman
# 1245  1935-02-06                          Alberta Vaughn
# 2547  1936-10-17                                Barbette
# 2806  1937-04-10                          Sepia Mae West
# 2876  1937-06-03                          Merry Pickford
# 1047  1934-12-27                              Babe Allen
# 2701  1936-12-10    Unnamed performer at 9 Mile House 11
# 4193  1944-05-13                             Rae Bourbon
# 2328  1936-05-29                          Merry Pickford
# 1370  1935-03-30         Unnamed performer at La Villa 3
# 1215  1935-02-02                              Fay Norman
# 4540  1948-03-27                               Dixie Lee
# 1944  1935-08-08                              Fay Norman
# 2199  1935-11-30                          Sepia Mae West
# 408   1933-08-01                          Billie Brannon
# 4392  1947-06-06              Billy ("Senorita") Herrera
# 1727  1935-07-13                              Fay Norman
# 4829  1949-11-01                             Adrian Ames
# 895   1934-10-19                             Adrian Ames
# 1308  1935-02-26                              Pep Murray
# 4149  1943-03-13              Billy ("Senorita") Herrera
#
#                                                  Source  \
# 1985     Jamestown Evening Journal, August 14, 1935, 14
# 2719         The Courier-Journal, December 11, 1936, 40
# 1487                 The Times Record, May 17, 1935, 10
# 3791               Detroit Free Press, May 11, 1940, 18
# 418   Variety Bills, Variety, 111, no. 9, August 8, ...
# 3955                                   Miami Herald, 15
# 39               Buffalo Courier, November 29, 1925, 54
# 3371            The Miami Herald, February 12, 1939, 54
# 307   HOLLYWOOD ADDS 2 NEW NIGHTERY SPOTS, Variety, ...
# 2198         The Chicago Defender, November 30, 1935, 8
# 460   X, "World's Fair Ladies Peel!!," Letter to the...
# 1396                           The News-Palladium, p. 9
# 3008          Nevada State Journal, November 6, 1937, 2
# 4436            The Miami Herald, September 4, 1947, 6B
# 3691               The Miami News, February 3, 1940, 6A
# 1322                                    Times-Union (4)
# 4405                The Miami Herald, June 12, 1947, 6B
# 4115                The Miami News, January 9, 1943, 6B
# 4257        The Cincinnati Enquirer, March 18, 1947, 19
# 108   The Brooklyn Standard Union, November 20, 1927...
# 4363           The Cincinnati Enquirer, May 9, 1947, 5B
# 4297        The Cincinnati Enquirer, April 28, 1947, 7B
# 1040               Miami Tribune, December 22, 1934, 11
# 4601  The Cincinnati Enquirer, August 22, 1948, 2, S...
# 691              The New York Sun, February 1, 1934, 27
# 3907                                  maye-10-23-41.jpg
# 60    Ironwood Daily Globe (Ironwood, Michigan), Apr...
# 2437                      Pittsburgh Post-Gazette, p. 6
# 21             The Yonkers Herald, December 16, 1924, 5
# 186   Vaudeville Reviews: The Palace, New York Sugar...
# 1245            The Times-Tribune, February 6, 1935, 12
# 2547  Vaudeville Reviews: Loew's State, New York Har...
# 2806                  Afro-American, April 10, 1937, 22
# 2876                The Evening Review, June 3, 1937, 6
# 1047               Miami Tribune, December 27, 1934, 10
# 2701     The American Israelite, December 10, 1936, P12
# 4193                       Daily News, May 13, 1944, 13
# 2328  The Wilmington, Delaware Morning News, May 29,...
# 1370                  The Billboard, March 30, 1935, 13
# 1215             The Times-Tribune, February 2, 1935, 3
# 4540            The Chicago Defender, March 27, 1948, 9
# 1944      Jamestown Evening Journal, August 8, 1935, 16
# 2199         The Chicago Defender, November 30, 1935, 8
# 408   Variety Bills, Variety, 111, no. 8, August 1, ...
# 4392                 The Miami Herald, June 6, 1947, 4D
# 1727       Jamestown Evening Journal, July 13, 1935, 10
# 4829           The Palm Beach Post, November 1, 1949, 8
# 895           New York Daily News, October 19, 1934, 58
# 1308            Syracuse Journal, February 26, 1935, 26
# 4149  The West Palm Beach, Florida Palm Beach Post, ...
#
#                                            Edge Comment Quote from source  \
# 1985
# 2719
# 1487
# 3791
# 418
# 3955
# 39
# 3371
# 307
# 2198
# 460
# 1396
# 3008
# 4436
# 3691
# 1322
# 4405
# 4115  TODO: Look closer at the detailed description ...
# 4257
# 108
# 4363
# 4297
# 1040
# 4601
# 691
# 3907
# 60
# 2437
# 21
# 186
# 1245
# 2547
# 2806
# 2876
# 1047
# 2701
# 4193
# 2328
# 1370
# 1215
# 4540
# 1944
# 2199
# 408
# 4392
# 1727
# 4829
# 895
# 1308
# 4149
#
#                              Comment on node: performer  \
# 1985      "In His Famous Fan Dance and the Continental"
# 2719
# 1487
# 3791
# 418
# 3955
# 39
# 3371
# 307
# 2198                                   "Brown Mae West"
# 460   "pansy comic" - does a fan dance in long under...
# 1396
# 3008
# 4436                       Billed as "Senorita Herrero"
# 3691
# 1322
# 4405                       Billed as "Senorita Herrero"
# 4115  Review of the performance; lots of description...
# 4257
# 108
# 4363
# 4297
# 1040
# 4601  "Female impersonators, somewhat rare in the oc...
# 691
# 3907
# 60
# 2437
# 21
# 186   originally scheduled to appear but was "pulled...
# 1245
# 2547
# 2806
# 2876
# 1047
# 2701
# 4193
# 2328
# 1370
# 1215
# 4540
# 1944
# 2199
# 408
# 4392                       "opens . . . tomorrow night"
# 1727
# 4829
# 895
# 1308
# 4149  "See the most exciting personality you ever sa...
#
#      Comment on node: venue Comment on node: city  \
# 1985
# 2719
# 1487
# 3791
# 418
# 3955
# 39
# 3371
# 307
# 2198
# 460
# 1396
# 3008
# 4436
# 3691
# 1322
# 4405
# 4115
# 4257
# 108
# 4363
# 4297
# 1040
# 4601
# 691
# 3907
# 60
# 2437
# 21
# 186
# 1245
# 2547
# 2806
# 2876
# 1047
# 2701
# 4193
# 2328
# 1370
# 1215
# 4540
# 1944
# 2199
# 408
# 4392
# 1727
# 4829
# 895
# 1308
# 4149
#
#                                  Comment on edge: revue  \
# 1985
# 2719                                       "14 Company"
# 1487
# 3791
# 418
# 3955
# 39
# 3371
# 307   "B.B.B.'s cellar does not feature any one perf...
# 2198
# 460
# 1396
# 3008
# 4436
# 3691
# 1322
# 4405
# 4115
# 4257
# 108
# 4363
# 4297
# 1040
# 4601
# 691
# 3907
# 60
# 2437
# 21
# 186
# 1245
# 2547
# 2806
# 2876
# 1047
# 2701                          "15 Female Impersonators"
# 4193
# 2328
# 1370
# 1215
# 4540
# 1944
# 2199
# 408
# 4392
# 1727
# 4829
# 895
# 1308
# 4149
#
#                                            Revue  \
# 1985                  Fay Norman's Gay Boy Revue
# 2719                  Fay Norman's Gay Boy Revue
# 1487                 Jack Mason's Play Boy Revue
# 3791          Karyl Norman's All-Star Male Revue
# 418
# 3955                   Gals, Girls, Molls, Dolls
# 39
# 3371
# 307                                Unnamed revue
# 2198
# 460
# 1396                          Boys Will Be Girls
# 3008
# 4436
# 3691
# 1322                  Jack Mason's Playboy Revue
# 4405
# 4115
# 4257                           The Gay Boy Revue
# 108                        The Tuneful Song Shop
# 4363                           The Gay Boy Revue
# 4297                           The Gay Boy Revue
# 1040                               Playboy Revue
# 4601                           The Gay Boy Revue
# 691           Jack Mason's Continental Boy Revue
# 3907
# 60
# 2437  Bobby LaRue and his 8 female impersonators
# 21                           The Gay Young Bride
# 186
# 1245
# 2547
# 2806
# 2876           Johnny Kaye and His Playboy Revue
# 1047                        Famous Playboy Revue
# 2701                  Fay Norman's Gay Boy Revue
# 4193
# 2328
# 1370                  Fay Norman's Gay Boy Revue
# 1215
# 4540
# 1944                  Fay Norman's Gay Boy Revue
# 2199                     Dock Weiler's Minstrels
# 408
# 4392
# 1727                  Fay Norman's Gay Boy Revue
# 4829                        Girl Hollywood Revue
# 895         Orchid & Scallion Revue, 2nd Edition
# 1308                  Fay Norman's All-Boy Revue
# 4149
#
#                                        Venue  Venue - Date grouping  \
# 1985            Terrace Gardens (Warren, PA)                    1.0
# 2719            The Paddock (Louisville, KY)                    1.0
# 1487                Echo Tavern (Albany, NY)                    2.0
# 3791            Club Frontenac (Detroit, MI)                    5.0
# 418                    K9 Club (Chicago, IL)                    3.0
# 3955              Boulevard Club (Miami, FL)                    1.0
# 39              Shea's Theatre (Buffalo, NY)                    1.0
# 3371          Kelly's Torch Club (Miami, FL)                    1.0
# 307               B.B.B.'s (Los Angeles, CA)                    1.0
# 2198       Lincoln Theatre (Los Angeles, CA)                    1.0
# 460             Club Le Masque (Chicago, IL)                    1.0
# 1396            Berkey's (Benton Harbor, MI)                    1.0
# 3008                The Dog House (Reno, NV)                    1.0
# 4436                     Paddock (Miami, FL)                    3.0
# 3691                  Ha-Ha Club (Miami, FL)                    4.0
# 1322                Echo Tavern (Albany, NY)                    2.0
# 4405                     Paddock (Miami, FL)                    2.0
# 4115               Latin Quarter (Miami, FL)                    1.0
# 4257            The Bandbox (Cincinnati, OH)                    1.0
# 108       Loew's Metropolitan (New York, NY)                    1.0
# 4363            The Bandbox (Cincinnati, OH)                    2.0
# 4297            The Bandbox (Cincinnati, OH)                    2.0
# 1040                  Torch Club (Miami, FL)                    4.0
# 4601          New Look Club (Cincinnati, OH)                    2.0
# 691              Club Richman (New York, NY)                    7.0
# 3907         Finocchio's (San Francisco, CA)                    5.0
# 60             Rialto Theatre (Ironwood, MI)                    1.0
# 2437          Italian Villa (Pittsburgh, PA)                    1.0
# 21          Warburton Theatre (New York, NY)                    1.0
# 186                The Palace (New York, NY)                    4.0
# 1245             Connie's Inn (New York, NY)                    1.0
# 2547             Loew's State (New York, NY)                    2.0
# 2806                   65 Club (Chicago, IL)                    1.0
# 2876    Club Washington (East Liverpool, OH)                    2.0
# 1047                  Torch Club (Miami, FL)                    4.0
# 2701           9 Mile House (Cincinnati, OH)                    1.0
# 4193        La Vie Parisienne (New York, NY)                    1.0
# 2328              USA Grill (Wilmington, DE)                    1.0
# 1370                 La Villa (Syracuse, NY)                    1.0
# 1215             Connie's Inn (New York, NY)                    1.0
# 4540              Joe’s Deluxe (Chicago, IL)                    8.0
# 1944            Terrace Gardens (Warren, PA)                    1.0
# 2199  Loew's State Theatre (Los Angeles, CA)                    1.0
# 408                    K9 Club (Chicago, IL)                    3.0
# 4392                     Paddock (Miami, FL)                    2.0
# 1727            Terrace Gardens (Warren, PA)                    1.0
# 4829     Three O'Clock Club (Palm Beach, FL)                    1.0
# 895              Club Florida (New York, NY)                    1.0
# 1308                 La Villa (Syracuse, NY)                    1.0
# 4149            Mike's (West Palm Beach, FL)                    1.0
#
#       Girvan Newman Modularity  Clauset-Newman-Moore Modularity
# 1985                         3                                1
# 2719                         3                                9
# 1487                         3                                1
# 3791                         3                                1
# 418                          3                                1
# 3955                         3                                2
# 39                           3                                1
# 3371                         3                                2
# 307                          3                               16
# 2198                         4                                5
# 460                          3                                2
# 1396                         3                                1
# 3008                         3                                2
# 4436                         3                                1
# 3691                         3                                1
# 1322                         3                                1
# 4405                         3                                1
# 4115                         3                                1
# 4257                         3                                1
# 108                          3                                1
# 4363                         3                                1
# 4297                         3                                1
# 1040                         3                                2
# 4601                         3                                1
# 691                          3                                1
# 3907                         3                                4
# 60                           0                                0
# 2437                         3                                4
# 21                           0                                0
# 186                          3                                1
# 1245                         3                                3
# 2547                         0                                0
# 2806                         4                                5
# 2876                         3                                4
# 1047                         3                                2
# 2701                         2                               10
# 4193                         3                                2
# 2328                         3                                4
# 1370                         3                                6
# 1215                         3                                6
# 4540                         4                                5
# 1944                         3                                6
# 2199                         4                                5
# 408                          3                                2
# 4392                         3                                1
# 1727                         3                                6
# 4829                         3                                7
# 895                          3                                7
# 1308                         3                                6
# 4149                         3                                1
