# %%
import pandas as pd
import networkx as nx
import re
from datetime import datetime, timedelta
from collections import OrderedDict

def clean(string):
    string = string.strip()
    string = re.sub(' +', ' ', string)
    if string == '-' or string == '–' or string == '—' or string == '?':
        string = ''
    
    if string == '':
        string = None

    return string

# %%
df = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vT0E0Y7txIa2pfBuusA1cd8X5OVhQ_D0qZC8D40KhTU3xB7McsPR2kuB7GH6ncmNT3nfjEYGbscOPp0/pub?gid=0&single=true&output=csv')

# %%
df = df.fillna('')
df['Date']
# Out:
# 0       1901-02-12
# 1       1904-04-30
# 2             1918
# 3             1920
# 4             1920
#            ...
# 7990
# 7991
# 7992
# 7993
# 7994
# Name: Date, Length: 7995, dtype: object

# %%
# df.columns

# %%
venue_data = {}

for ix, row in df.iterrows():
    if row['Exclude from visualization'] or row['Unsure whether drag artist']:
        continue
        
    if clean(row['Performer first-name']) and clean(row['Performer last-name']):
        performer = clean(row['Performer first-name']) + ' ' + clean(row['Performer last-name'])
    else:
        if row['Normalized performer']:
            performer = clean(row['Normalized performer'])
        else:
            performer = clean(row['Performer'])

    venue = clean(row['Venue'])
    
    if row['Normalized City']:
        city = clean(row['Normalized City'])
    else:
        city = clean(row['City'])
        
    date_precision = ''
    
    if row['Date']:
        row['Date'] = row['Date'].replace('?', '')
        try:
            date = datetime.strptime(row['Date'], '%Y-%m-%d')
            date_precision = 'full'
        except:
            try:
                date = datetime.strptime(row['Date'], '%Y-%m')
                date_precision = 'year-month'
            except:
                try:
                    date = datetime.strptime(row['Date'], '%Y')
                    date_precision = 'year'
                except:
                    print(row['Date'])
                    date = None
    else:
        date = None
        
    # We only want performers and venues here
    if not performer or not venue:
        continue
        
    source = row['Source clean']
    if not source:
        source = row['Source']
        
    if not venue in venue_data:
        venue_data[venue] = {'full_dates': OrderedDict(), 'years': OrderedDict(), 'year-months': OrderedDict()}

    if date_precision == 'full' and not date in venue_data[venue]['full_dates']:
        venue_data[venue]['full_dates'][date] = []

    if date_precision == 'year-month' and not date in venue_data[venue]['year-months']:
        venue_data[venue]['year-months'][date] = []

    if date_precision == 'year' and not date in venue_data[venue]['years']:
        venue_data[venue]['years'][date] = []

    if date_precision == 'full':
        venue_data[venue]['full_dates'][date].append({
            'performer': performer,
            'source': source
        })
        
    if date_precision == 'year-month':
        venue_data[venue]['year-months'][date].append({
            'performer': performer,
            'source': source
        })
    
    if date_precision == 'year':
        venue_data[venue]['years'][date].append({
            'performer': performer,
            'source': source
        })

# %%
G = nx.DiGraph()

process, i = 50, 0

for venue, d in venue_data.items():
    i+=1
    #if i > process:
    #    continue
        
    print(venue)
    
    for date, datapoints in d['full_dates'].items():
        start_date = date - timedelta(days=7)
        end_date = date + timedelta(days=7)
        dates = [start_date + timedelta(days=x) for x in range((end_date-start_date).days + 1)]
        for data in datapoints:
            print({x:y for x,y in venue_data[venue]['full_dates'].items() if x in dates and y != data})
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# {datetime.datetime(1939, 2, 4, 0, 0): [{'performer': 'Jean La Monte', 'source': 'The Miami News, February 4, 1939, 5'}, {'performer': 'Sonny La Ray', 'source': 'The Miami News, February 4, 1939, 5'}]}
# Elk's Rendezvous
# {datetime.datetime(1939, 2, 18, 0, 0): [{'performer': 'Phil Black', 'source': 'The Chicago Defender, February 18, 1939, 19'}]}
# Pioneer Club
# {datetime.datetime(1939, 4, 22, 0, 0): [{'performer': 'Max Lengel', 'source': 'Daily News, April 22, 1939, 22'}]}
# {datetime.datetime(1939, 5, 13, 0, 0): [{'performer': 'Max Lengel', 'source': 'Daily News, May 13, 1939, 22'}]}
# {datetime.datetime(1939, 6, 3, 0, 0): [{'performer': 'Max Lengel', 'source': 'Daily News, 3 June 1939, 22'}]}
# {datetime.datetime(1939, 6, 30, 0, 0): [{'performer': 'Sammy Grand', 'source': 'The Post-Star, June 30, 1939, 22'}], datetime.datetime(1939, 7, 1, 0, 0): [{'performer': 'Sammy Grand', 'source': 'The Post-Star, July 1, 1939, 10'}]}
# {datetime.datetime(1939, 6, 30, 0, 0): [{'performer': 'Sammy Grand', 'source': 'The Post-Star, June 30, 1939, 22'}], datetime.datetime(1939, 7, 1, 0, 0): [{'performer': 'Sammy Grand', 'source': 'The Post-Star, July 1, 1939, 10'}], datetime.datetime(1939, 7, 8, 0, 0): [{'performer': 'Sammy Grand', 'source': 'The Post-Star, July 8, 1939, 10'}]}
# {datetime.datetime(1939, 7, 1, 0, 0): [{'performer': 'Sammy Grand', 'source': 'The Post-Star, July 1, 1939, 10'}], datetime.datetime(1939, 7, 8, 0, 0): [{'performer': 'Sammy Grand', 'source': 'The Post-Star, July 8, 1939, 10'}]}
# {datetime.datetime(1939, 11, 8, 0, 0): [{'performer': 'Max Lengel', 'source': 'Daily News, November 8, 1939, 48'}], datetime.datetime(1939, 11, 10, 0, 0): [{'performer': 'Bobby Dell', 'source': 'The Brooklyn Daily Eagle, November 10, 1939, 19'}, {'performer': 'Max Lengel', 'source': 'The Brooklyn Daily Eagle, November 10, 1939, 19'}], datetime.datetime(1939, 11, 15, 0, 0): [{'performer': 'Max Lengel', 'source': 'Daily News, November 15, 1939, 22'}]}
# {datetime.datetime(1939, 11, 8, 0, 0): [{'performer': 'Max Lengel', 'source': 'Daily News, November 8, 1939, 48'}], datetime.datetime(1939, 11, 10, 0, 0): [{'performer': 'Bobby Dell', 'source': 'The Brooklyn Daily Eagle, November 10, 1939, 19'}, {'performer': 'Max Lengel', 'source': 'The Brooklyn Daily Eagle, November 10, 1939, 19'}], datetime.datetime(1939, 11, 15, 0, 0): [{'performer': 'Max Lengel', 'source': 'Daily News, November 15, 1939, 22'}]}
# {datetime.datetime(1939, 11, 8, 0, 0): [{'performer': 'Max Lengel', 'source': 'Daily News, November 8, 1939, 48'}], datetime.datetime(1939, 11, 10, 0, 0): [{'performer': 'Bobby Dell', 'source': 'The Brooklyn Daily Eagle, November 10, 1939, 19'}, {'performer': 'Max Lengel', 'source': 'The Brooklyn Daily Eagle, November 10, 1939, 19'}], datetime.datetime(1939, 11, 15, 0, 0): [{'performer': 'Max Lengel', 'source': 'Daily News, November 15, 1939, 22'}]}
# {datetime.datetime(1939, 11, 8, 0, 0): [{'performer': 'Max Lengel', 'source': 'Daily News, November 8, 1939, 48'}], datetime.datetime(1939, 11, 10, 0, 0): [{'performer': 'Bobby Dell', 'source': 'The Brooklyn Daily Eagle, November 10, 1939, 19'}, {'performer': 'Max Lengel', 'source': 'The Brooklyn Daily Eagle, November 10, 1939, 19'}], datetime.datetime(1939, 11, 15, 0, 0): [{'performer': 'Max Lengel', 'source': 'Daily News, November 15, 1939, 22'}]}
# {datetime.datetime(1939, 11, 24, 0, 0): [{'performer': 'Max Lengel', 'source': 'The Brooklyn Daily Eagle, November 24, 1939, 10'}, {'performer': 'Max Lengel', 'source': 'Brooklyn Eagle, November 24, 1939, 10'}, {'performer': 'Max Lengel', 'source': 'Brooklyn Eagle, November 24, 1939, 10'}], datetime.datetime(1939, 12, 1, 0, 0): [{'performer': 'Max Lengel', 'source': 'The Brooklyn Daily Eagle, December 1, 1939, 12'}]}
# {datetime.datetime(1939, 11, 24, 0, 0): [{'performer': 'Max Lengel', 'source': 'The Brooklyn Daily Eagle, November 24, 1939, 10'}, {'performer': 'Max Lengel', 'source': 'Brooklyn Eagle, November 24, 1939, 10'}, {'performer': 'Max Lengel', 'source': 'Brooklyn Eagle, November 24, 1939, 10'}], datetime.datetime(1939, 12, 1, 0, 0): [{'performer': 'Max Lengel', 'source': 'The Brooklyn Daily Eagle, December 1, 1939, 12'}]}
# {datetime.datetime(1939, 11, 24, 0, 0): [{'performer': 'Max Lengel', 'source': 'The Brooklyn Daily Eagle, November 24, 1939, 10'}, {'performer': 'Max Lengel', 'source': 'Brooklyn Eagle, November 24, 1939, 10'}, {'performer': 'Max Lengel', 'source': 'Brooklyn Eagle, November 24, 1939, 10'}], datetime.datetime(1939, 12, 1, 0, 0): [{'performer': 'Max Lengel', 'source': 'The Brooklyn Daily Eagle, December 1, 1939, 12'}]}
# {datetime.datetime(1939, 11, 24, 0, 0): [{'performer': 'Max Lengel', 'source': 'The Brooklyn Daily Eagle, November 24, 1939, 10'}, {'performer': 'Max Lengel', 'source': 'Brooklyn Eagle, November 24, 1939, 10'}, {'performer': 'Max Lengel', 'source': 'Brooklyn Eagle, November 24, 1939, 10'}], datetime.datetime(1939, 12, 1, 0, 0): [{'performer': 'Max Lengel', 'source': 'The Brooklyn Daily Eagle, December 1, 1939, 12'}]}
# {datetime.datetime(1939, 12, 15, 0, 0): [{'performer': 'Max Lengel', 'source': 'The Brooklyn Daily Eagle, December 15, 1939, 19'}], datetime.datetime(1939, 12, 22, 0, 0): [{'performer': 'Max Lengel', 'source': 'The Brooklyn Daily Eagle, December 22, 1939, 8'}]}
# {datetime.datetime(1939, 12, 15, 0, 0): [{'performer': 'Max Lengel', 'source': 'The Brooklyn Daily Eagle, December 15, 1939, 19'}], datetime.datetime(1939, 12, 22, 0, 0): [{'performer': 'Max Lengel', 'source': 'The Brooklyn Daily Eagle, December 22, 1939, 8'}], datetime.datetime(1939, 12, 29, 0, 0): [{'performer': 'Max Lengel', 'source': 'The Brooklyn Daily Eagle, December 29, 1939, 9'}]}
# {datetime.datetime(1939, 12, 22, 0, 0): [{'performer': 'Max Lengel', 'source': 'The Brooklyn Daily Eagle, December 22, 1939, 8'}], datetime.datetime(1939, 12, 29, 0, 0): [{'performer': 'Max Lengel', 'source': 'The Brooklyn Daily Eagle, December 29, 1939, 9'}]}
# Sailer Hotel
# {datetime.datetime(1939, 5, 5, 0, 0): [{'performer': 'Lee Carroll', 'source': 'The Evening Independent, May 5, 1939, 1'}]}
# Paddock
# {datetime.datetime(1939, 5, 20, 0, 0): [{'performer': 'Jackie Maye', 'source': 'maye-jackie-05-20-39-miami daily news.jpg'}]}
# {datetime.datetime(1947, 6, 6, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 6, 1947, 4D'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 6, 1947, 4D'}], datetime.datetime(1947, 6, 7, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 7, 1947, 2B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 7, 1947, 9A'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 7, 1947, 3'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 7, 1947, 10'}], datetime.datetime(1947, 6, 8, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 8, 1947, 6D'}], datetime.datetime(1947, 6, 9, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 9, 1947, 11A'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 9, 1947, 4A'}], datetime.datetime(1947, 6, 10, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 10, 1947, 7A'}], datetime.datetime(1947, 6, 11, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 11, 1947, 8B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 11, 1947, 4A'}], datetime.datetime(1947, 6, 12, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 12, 1947, 6B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 12, 1947, 14A'}]}
# {datetime.datetime(1947, 6, 6, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 6, 1947, 4D'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 6, 1947, 4D'}], datetime.datetime(1947, 6, 7, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 7, 1947, 2B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 7, 1947, 9A'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 7, 1947, 3'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 7, 1947, 10'}], datetime.datetime(1947, 6, 8, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 8, 1947, 6D'}], datetime.datetime(1947, 6, 9, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 9, 1947, 11A'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 9, 1947, 4A'}], datetime.datetime(1947, 6, 10, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 10, 1947, 7A'}], datetime.datetime(1947, 6, 11, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 11, 1947, 8B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 11, 1947, 4A'}], datetime.datetime(1947, 6, 12, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 12, 1947, 6B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 12, 1947, 14A'}]}
# {datetime.datetime(1947, 6, 6, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 6, 1947, 4D'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 6, 1947, 4D'}], datetime.datetime(1947, 6, 7, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 7, 1947, 2B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 7, 1947, 9A'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 7, 1947, 3'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 7, 1947, 10'}], datetime.datetime(1947, 6, 8, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 8, 1947, 6D'}], datetime.datetime(1947, 6, 9, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 9, 1947, 11A'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 9, 1947, 4A'}], datetime.datetime(1947, 6, 10, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 10, 1947, 7A'}], datetime.datetime(1947, 6, 11, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 11, 1947, 8B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 11, 1947, 4A'}], datetime.datetime(1947, 6, 12, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 12, 1947, 6B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 12, 1947, 14A'}], datetime.datetime(1947, 6, 14, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 14, 1947, 10A'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 14, 1947, 3'}]}
# {datetime.datetime(1947, 6, 6, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 6, 1947, 4D'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 6, 1947, 4D'}], datetime.datetime(1947, 6, 7, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 7, 1947, 2B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 7, 1947, 9A'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 7, 1947, 3'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 7, 1947, 10'}], datetime.datetime(1947, 6, 8, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 8, 1947, 6D'}], datetime.datetime(1947, 6, 9, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 9, 1947, 11A'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 9, 1947, 4A'}], datetime.datetime(1947, 6, 10, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 10, 1947, 7A'}], datetime.datetime(1947, 6, 11, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 11, 1947, 8B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 11, 1947, 4A'}], datetime.datetime(1947, 6, 12, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 12, 1947, 6B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 12, 1947, 14A'}], datetime.datetime(1947, 6, 14, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 14, 1947, 10A'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 14, 1947, 3'}]}
# {datetime.datetime(1947, 6, 6, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 6, 1947, 4D'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 6, 1947, 4D'}], datetime.datetime(1947, 6, 7, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 7, 1947, 2B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 7, 1947, 9A'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 7, 1947, 3'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 7, 1947, 10'}], datetime.datetime(1947, 6, 8, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 8, 1947, 6D'}], datetime.datetime(1947, 6, 9, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 9, 1947, 11A'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 9, 1947, 4A'}], datetime.datetime(1947, 6, 10, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 10, 1947, 7A'}], datetime.datetime(1947, 6, 11, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 11, 1947, 8B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 11, 1947, 4A'}], datetime.datetime(1947, 6, 12, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 12, 1947, 6B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 12, 1947, 14A'}], datetime.datetime(1947, 6, 14, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 14, 1947, 10A'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 14, 1947, 3'}]}
# {datetime.datetime(1947, 6, 6, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 6, 1947, 4D'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 6, 1947, 4D'}], datetime.datetime(1947, 6, 7, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 7, 1947, 2B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 7, 1947, 9A'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 7, 1947, 3'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 7, 1947, 10'}], datetime.datetime(1947, 6, 8, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 8, 1947, 6D'}], datetime.datetime(1947, 6, 9, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 9, 1947, 11A'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 9, 1947, 4A'}], datetime.datetime(1947, 6, 10, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 10, 1947, 7A'}], datetime.datetime(1947, 6, 11, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 11, 1947, 8B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 11, 1947, 4A'}], datetime.datetime(1947, 6, 12, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 12, 1947, 6B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 12, 1947, 14A'}], datetime.datetime(1947, 6, 14, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 14, 1947, 10A'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 14, 1947, 3'}]}
# {datetime.datetime(1947, 6, 6, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 6, 1947, 4D'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 6, 1947, 4D'}], datetime.datetime(1947, 6, 7, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 7, 1947, 2B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 7, 1947, 9A'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 7, 1947, 3'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 7, 1947, 10'}], datetime.datetime(1947, 6, 8, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 8, 1947, 6D'}], datetime.datetime(1947, 6, 9, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 9, 1947, 11A'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 9, 1947, 4A'}], datetime.datetime(1947, 6, 10, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 10, 1947, 7A'}], datetime.datetime(1947, 6, 11, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 11, 1947, 8B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 11, 1947, 4A'}], datetime.datetime(1947, 6, 12, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 12, 1947, 6B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 12, 1947, 14A'}], datetime.datetime(1947, 6, 14, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 14, 1947, 10A'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 14, 1947, 3'}], datetime.datetime(1947, 6, 15, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 15, 1947, 11C'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 15, 1947, 6D'}]}
# {datetime.datetime(1947, 6, 6, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 6, 1947, 4D'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 6, 1947, 4D'}], datetime.datetime(1947, 6, 7, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 7, 1947, 2B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 7, 1947, 9A'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 7, 1947, 3'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 7, 1947, 10'}], datetime.datetime(1947, 6, 8, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 8, 1947, 6D'}], datetime.datetime(1947, 6, 9, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 9, 1947, 11A'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 9, 1947, 4A'}], datetime.datetime(1947, 6, 10, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 10, 1947, 7A'}], datetime.datetime(1947, 6, 11, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 11, 1947, 8B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 11, 1947, 4A'}], datetime.datetime(1947, 6, 12, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 12, 1947, 6B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 12, 1947, 14A'}], datetime.datetime(1947, 6, 14, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 14, 1947, 10A'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 14, 1947, 3'}], datetime.datetime(1947, 6, 15, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 15, 1947, 11C'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 15, 1947, 6D'}], datetime.datetime(1947, 6, 16, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 16, 1947, 3B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 16, 1947, 4B'}]}
# {datetime.datetime(1947, 6, 6, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 6, 1947, 4D'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 6, 1947, 4D'}], datetime.datetime(1947, 6, 7, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 7, 1947, 2B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 7, 1947, 9A'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 7, 1947, 3'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 7, 1947, 10'}], datetime.datetime(1947, 6, 8, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 8, 1947, 6D'}], datetime.datetime(1947, 6, 9, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 9, 1947, 11A'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 9, 1947, 4A'}], datetime.datetime(1947, 6, 10, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 10, 1947, 7A'}], datetime.datetime(1947, 6, 11, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 11, 1947, 8B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 11, 1947, 4A'}], datetime.datetime(1947, 6, 12, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 12, 1947, 6B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 12, 1947, 14A'}], datetime.datetime(1947, 6, 14, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 14, 1947, 10A'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 14, 1947, 3'}], datetime.datetime(1947, 6, 15, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 15, 1947, 11C'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 15, 1947, 6D'}], datetime.datetime(1947, 6, 16, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 16, 1947, 3B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 16, 1947, 4B'}]}
# {datetime.datetime(1947, 6, 6, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 6, 1947, 4D'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 6, 1947, 4D'}], datetime.datetime(1947, 6, 7, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 7, 1947, 2B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 7, 1947, 9A'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 7, 1947, 3'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 7, 1947, 10'}], datetime.datetime(1947, 6, 8, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 8, 1947, 6D'}], datetime.datetime(1947, 6, 9, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 9, 1947, 11A'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 9, 1947, 4A'}], datetime.datetime(1947, 6, 10, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 10, 1947, 7A'}], datetime.datetime(1947, 6, 11, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 11, 1947, 8B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 11, 1947, 4A'}], datetime.datetime(1947, 6, 12, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 12, 1947, 6B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 12, 1947, 14A'}], datetime.datetime(1947, 6, 14, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 14, 1947, 10A'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 14, 1947, 3'}], datetime.datetime(1947, 6, 15, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 15, 1947, 11C'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 15, 1947, 6D'}], datetime.datetime(1947, 6, 16, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 16, 1947, 3B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 16, 1947, 4B'}], datetime.datetime(1947, 6, 17, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 17, 1947, 5B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 17, 1947, 6A'}]}
# {datetime.datetime(1947, 6, 6, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 6, 1947, 4D'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 6, 1947, 4D'}], datetime.datetime(1947, 6, 7, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 7, 1947, 2B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 7, 1947, 9A'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 7, 1947, 3'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 7, 1947, 10'}], datetime.datetime(1947, 6, 8, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 8, 1947, 6D'}], datetime.datetime(1947, 6, 9, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 9, 1947, 11A'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 9, 1947, 4A'}], datetime.datetime(1947, 6, 10, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 10, 1947, 7A'}], datetime.datetime(1947, 6, 11, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 11, 1947, 8B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 11, 1947, 4A'}], datetime.datetime(1947, 6, 12, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 12, 1947, 6B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 12, 1947, 14A'}], datetime.datetime(1947, 6, 14, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 14, 1947, 10A'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 14, 1947, 3'}], datetime.datetime(1947, 6, 15, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 15, 1947, 11C'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 15, 1947, 6D'}], datetime.datetime(1947, 6, 16, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 16, 1947, 3B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 16, 1947, 4B'}], datetime.datetime(1947, 6, 17, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 17, 1947, 5B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 17, 1947, 6A'}], datetime.datetime(1947, 6, 18, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 18, 1947, 6B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 18, 1947, 6A'}]}
# {datetime.datetime(1947, 6, 6, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 6, 1947, 4D'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 6, 1947, 4D'}], datetime.datetime(1947, 6, 7, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 7, 1947, 2B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 7, 1947, 9A'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 7, 1947, 3'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 7, 1947, 10'}], datetime.datetime(1947, 6, 8, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 8, 1947, 6D'}], datetime.datetime(1947, 6, 9, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 9, 1947, 11A'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 9, 1947, 4A'}], datetime.datetime(1947, 6, 10, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 10, 1947, 7A'}], datetime.datetime(1947, 6, 11, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 11, 1947, 8B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 11, 1947, 4A'}], datetime.datetime(1947, 6, 12, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 12, 1947, 6B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 12, 1947, 14A'}], datetime.datetime(1947, 6, 14, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 14, 1947, 10A'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 14, 1947, 3'}], datetime.datetime(1947, 6, 15, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 15, 1947, 11C'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 15, 1947, 6D'}], datetime.datetime(1947, 6, 16, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 16, 1947, 3B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 16, 1947, 4B'}], datetime.datetime(1947, 6, 17, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 17, 1947, 5B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 17, 1947, 6A'}], datetime.datetime(1947, 6, 18, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 18, 1947, 6B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 18, 1947, 6A'}]}
# {datetime.datetime(1947, 6, 6, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 6, 1947, 4D'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 6, 1947, 4D'}], datetime.datetime(1947, 6, 7, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 7, 1947, 2B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 7, 1947, 9A'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 7, 1947, 3'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 7, 1947, 10'}], datetime.datetime(1947, 6, 8, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 8, 1947, 6D'}], datetime.datetime(1947, 6, 9, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 9, 1947, 11A'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 9, 1947, 4A'}], datetime.datetime(1947, 6, 10, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 10, 1947, 7A'}], datetime.datetime(1947, 6, 11, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 11, 1947, 8B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 11, 1947, 4A'}], datetime.datetime(1947, 6, 12, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 12, 1947, 6B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 12, 1947, 14A'}], datetime.datetime(1947, 6, 14, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 14, 1947, 10A'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 14, 1947, 3'}], datetime.datetime(1947, 6, 15, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 15, 1947, 11C'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 15, 1947, 6D'}], datetime.datetime(1947, 6, 16, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 16, 1947, 3B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 16, 1947, 4B'}], datetime.datetime(1947, 6, 17, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 17, 1947, 5B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 17, 1947, 6A'}], datetime.datetime(1947, 6, 18, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 18, 1947, 6B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 18, 1947, 6A'}], datetime.datetime(1947, 6, 19, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 19, 1947, 14A'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 19, 1947, 14A'}]}
# {datetime.datetime(1947, 6, 6, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 6, 1947, 4D'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 6, 1947, 4D'}], datetime.datetime(1947, 6, 7, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 7, 1947, 2B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 7, 1947, 9A'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 7, 1947, 3'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 7, 1947, 10'}], datetime.datetime(1947, 6, 8, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 8, 1947, 6D'}], datetime.datetime(1947, 6, 9, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 9, 1947, 11A'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 9, 1947, 4A'}], datetime.datetime(1947, 6, 10, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 10, 1947, 7A'}], datetime.datetime(1947, 6, 11, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 11, 1947, 8B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 11, 1947, 4A'}], datetime.datetime(1947, 6, 12, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 12, 1947, 6B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 12, 1947, 14A'}], datetime.datetime(1947, 6, 14, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 14, 1947, 10A'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 14, 1947, 3'}], datetime.datetime(1947, 6, 15, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 15, 1947, 11C'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 15, 1947, 6D'}], datetime.datetime(1947, 6, 16, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 16, 1947, 3B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 16, 1947, 4B'}], datetime.datetime(1947, 6, 17, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 17, 1947, 5B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 17, 1947, 6A'}], datetime.datetime(1947, 6, 18, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 18, 1947, 6B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 18, 1947, 6A'}], datetime.datetime(1947, 6, 19, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 19, 1947, 14A'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 19, 1947, 14A'}]}
# {datetime.datetime(1947, 6, 7, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 7, 1947, 2B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 7, 1947, 9A'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 7, 1947, 3'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 7, 1947, 10'}], datetime.datetime(1947, 6, 8, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 8, 1947, 6D'}], datetime.datetime(1947, 6, 9, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 9, 1947, 11A'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 9, 1947, 4A'}], datetime.datetime(1947, 6, 10, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 10, 1947, 7A'}], datetime.datetime(1947, 6, 11, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 11, 1947, 8B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 11, 1947, 4A'}], datetime.datetime(1947, 6, 12, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 12, 1947, 6B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 12, 1947, 14A'}], datetime.datetime(1947, 6, 14, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 14, 1947, 10A'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 14, 1947, 3'}], datetime.datetime(1947, 6, 15, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 15, 1947, 11C'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 15, 1947, 6D'}], datetime.datetime(1947, 6, 16, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 16, 1947, 3B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 16, 1947, 4B'}], datetime.datetime(1947, 6, 17, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 17, 1947, 5B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 17, 1947, 6A'}], datetime.datetime(1947, 6, 18, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 18, 1947, 6B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 18, 1947, 6A'}], datetime.datetime(1947, 6, 19, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 19, 1947, 14A'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 19, 1947, 14A'}]}
# {datetime.datetime(1947, 6, 7, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 7, 1947, 2B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 7, 1947, 9A'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 7, 1947, 3'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 7, 1947, 10'}], datetime.datetime(1947, 6, 8, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 8, 1947, 6D'}], datetime.datetime(1947, 6, 9, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 9, 1947, 11A'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 9, 1947, 4A'}], datetime.datetime(1947, 6, 10, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 10, 1947, 7A'}], datetime.datetime(1947, 6, 11, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 11, 1947, 8B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 11, 1947, 4A'}], datetime.datetime(1947, 6, 12, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 12, 1947, 6B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 12, 1947, 14A'}], datetime.datetime(1947, 6, 14, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 14, 1947, 10A'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 14, 1947, 3'}], datetime.datetime(1947, 6, 15, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 15, 1947, 11C'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 15, 1947, 6D'}], datetime.datetime(1947, 6, 16, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 16, 1947, 3B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 16, 1947, 4B'}], datetime.datetime(1947, 6, 17, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 17, 1947, 5B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 17, 1947, 6A'}], datetime.datetime(1947, 6, 18, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 18, 1947, 6B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 18, 1947, 6A'}], datetime.datetime(1947, 6, 19, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 19, 1947, 14A'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 19, 1947, 14A'}]}
# {datetime.datetime(1947, 6, 8, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 8, 1947, 6D'}], datetime.datetime(1947, 6, 9, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 9, 1947, 11A'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 9, 1947, 4A'}], datetime.datetime(1947, 6, 10, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 10, 1947, 7A'}], datetime.datetime(1947, 6, 11, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 11, 1947, 8B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 11, 1947, 4A'}], datetime.datetime(1947, 6, 12, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 12, 1947, 6B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 12, 1947, 14A'}], datetime.datetime(1947, 6, 14, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 14, 1947, 10A'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 14, 1947, 3'}], datetime.datetime(1947, 6, 15, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 15, 1947, 11C'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 15, 1947, 6D'}], datetime.datetime(1947, 6, 16, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 16, 1947, 3B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 16, 1947, 4B'}], datetime.datetime(1947, 6, 17, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 17, 1947, 5B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 17, 1947, 6A'}], datetime.datetime(1947, 6, 18, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 18, 1947, 6B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 18, 1947, 6A'}], datetime.datetime(1947, 6, 19, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 19, 1947, 14A'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 19, 1947, 14A'}]}
# {datetime.datetime(1947, 6, 8, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 8, 1947, 6D'}], datetime.datetime(1947, 6, 9, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 9, 1947, 11A'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 9, 1947, 4A'}], datetime.datetime(1947, 6, 10, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 10, 1947, 7A'}], datetime.datetime(1947, 6, 11, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 11, 1947, 8B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 11, 1947, 4A'}], datetime.datetime(1947, 6, 12, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 12, 1947, 6B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 12, 1947, 14A'}], datetime.datetime(1947, 6, 14, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 14, 1947, 10A'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 14, 1947, 3'}], datetime.datetime(1947, 6, 15, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 15, 1947, 11C'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 15, 1947, 6D'}], datetime.datetime(1947, 6, 16, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 16, 1947, 3B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 16, 1947, 4B'}], datetime.datetime(1947, 6, 17, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 17, 1947, 5B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 17, 1947, 6A'}], datetime.datetime(1947, 6, 18, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 18, 1947, 6B'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 18, 1947, 6A'}], datetime.datetime(1947, 6, 19, 0, 0): [{'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami Herald, June 19, 1947, 14A'}, {'performer': 'Billy ("Senorita") Herrera', 'source': 'The Miami News, June 19, 1947, 14A'}]}
# ...
# Chi Chi
# {datetime.datetime(1964, 11, 18, 0, 0): [{'performer': 'Unnamed performer at Chi Chi Club', 'source': 'Night Club Reviews: Chi Chi, S.F. Sanf., Variety, 236, no. 13, November 18, 1964, 58'}]}
# Montclair
# {datetime.datetime(1965, 6, 11, 0, 0): [{'performer': 'Frankie Quinn', 'source': 'Daily News, June 11, 1965, 73'}, {'performer': 'Frankie Quinn', 'source': 'Daily News, 11 June 1965, 73'}, {'performer': 'Jackie Small', 'source': 'Daily News, 11 June 1965, 73'}]}
# {datetime.datetime(1965, 6, 11, 0, 0): [{'performer': 'Frankie Quinn', 'source': 'Daily News, June 11, 1965, 73'}, {'performer': 'Frankie Quinn', 'source': 'Daily News, 11 June 1965, 73'}, {'performer': 'Jackie Small', 'source': 'Daily News, 11 June 1965, 73'}]}
# {datetime.datetime(1965, 6, 11, 0, 0): [{'performer': 'Frankie Quinn', 'source': 'Daily News, June 11, 1965, 73'}, {'performer': 'Frankie Quinn', 'source': 'Daily News, 11 June 1965, 73'}, {'performer': 'Jackie Small', 'source': 'Daily News, 11 June 1965, 73'}]}
# Frolic Room
# {datetime.datetime(1965, 6, 12, 0, 0): [{'performer': 'Adrian Ames', 'source': 'The San Francisco Examiner, June 12, 1965, 20'}], datetime.datetime(1965, 6, 13, 0, 0): [{'performer': 'Adrian Ames', 'source': 'Entertainment Guide, The San Francisco Examiner, June 13, 1965, 173'}, {'performer': 'Adrian Ames', 'source': 'The San Francisco Examiner, June 13, 1965, 7'}]}
# {datetime.datetime(1965, 6, 12, 0, 0): [{'performer': 'Adrian Ames', 'source': 'The San Francisco Examiner, June 12, 1965, 20'}], datetime.datetime(1965, 6, 13, 0, 0): [{'performer': 'Adrian Ames', 'source': 'Entertainment Guide, The San Francisco Examiner, June 13, 1965, 173'}, {'performer': 'Adrian Ames', 'source': 'The San Francisco Examiner, June 13, 1965, 7'}]}
# {datetime.datetime(1965, 6, 12, 0, 0): [{'performer': 'Adrian Ames', 'source': 'The San Francisco Examiner, June 12, 1965, 20'}], datetime.datetime(1965, 6, 13, 0, 0): [{'performer': 'Adrian Ames', 'source': 'Entertainment Guide, The San Francisco Examiner, June 13, 1965, 173'}, {'performer': 'Adrian Ames', 'source': 'The San Francisco Examiner, June 13, 1965, 7'}]}
# Grubstake Theatre
# {datetime.datetime(1965, 6, 19, 0, 0): [{'performer': 'Rae Bourbon', 'source': 'CSGT ??? ILL should be requested'}]}
# Apache Lounge
# {datetime.datetime(1966, 10, 5, 0, 0): [{'performer': 'Carmen Del Carmen', 'source': 'Safe Refuge, Variety, 244, no. 7, October 5, 1966, 2'}]}
# The Glade
# {datetime.datetime(1967, 2, 15, 0, 0): [{'performer': 'Prince Hanalei', 'source': '67-021567-glade'}]}
# {datetime.datetime(1975, 2, 14, 0, 0): [{'performer': 'Prince Hanalei', 'source': '75-021475-glade'}]}
# Clouds Hotel
# {datetime.datetime(1967, 9, 8, 0, 0): [{'performer': 'Adrian Ames', 'source': 'Honolulu Star-Bulletin, September 8, 1967, B5'}], datetime.datetime(1967, 9, 11, 0, 0): [{'performer': 'Adrian Ames', 'source': 'The Honolulu Advertiser, September 11, 1967, B5'}], datetime.datetime(1967, 9, 15, 0, 0): [{'performer': 'Adrian Ames', 'source': 'The Honolulu Advertiser, September 15, 1967, E7'}]}
# {datetime.datetime(1967, 9, 8, 0, 0): [{'performer': 'Adrian Ames', 'source': 'Honolulu Star-Bulletin, September 8, 1967, B5'}], datetime.datetime(1967, 9, 11, 0, 0): [{'performer': 'Adrian Ames', 'source': 'The Honolulu Advertiser, September 11, 1967, B5'}], datetime.datetime(1967, 9, 15, 0, 0): [{'performer': 'Adrian Ames', 'source': 'The Honolulu Advertiser, September 15, 1967, E7'}]}
# {datetime.datetime(1967, 9, 8, 0, 0): [{'performer': 'Adrian Ames', 'source': 'Honolulu Star-Bulletin, September 8, 1967, B5'}], datetime.datetime(1967, 9, 11, 0, 0): [{'performer': 'Adrian Ames', 'source': 'The Honolulu Advertiser, September 11, 1967, B5'}], datetime.datetime(1967, 9, 15, 0, 0): [{'performer': 'Adrian Ames', 'source': 'The Honolulu Advertiser, September 15, 1967, E7'}]}
# Jan Hus Playhouse
# {datetime.datetime(1968, 2, 14, 0, 0): [{'performer': 'Lynne Carter', 'source': 'Norman A. King, Variety, 249, no. 13, February 14, 1968, 63'}, {'performer': 'Lynne Carter', 'source': 'Legit Bits, Variety, 249, no. 13, February 14, 1968, 66'}]}
# {datetime.datetime(1968, 2, 14, 0, 0): [{'performer': 'Lynne Carter', 'source': 'Norman A. King, Variety, 249, no. 13, February 14, 1968, 63'}, {'performer': 'Lynne Carter', 'source': 'Legit Bits, Variety, 249, no. 13, February 14, 1968, 66'}]}
# Antonio's
# {datetime.datetime(1968, 10, 21, 0, 0): [{'performer': 'Dave Davis', 'source': 'Alabama Journal (Montgomery, Alabama), October 21, 1968, 11'}], datetime.datetime(1968, 10, 22, 0, 0): [{'performer': 'Dave Davis', 'source': 'The Montgomery, Alabama Montgomery Advertiser, October 22, 1968, 16'}], datetime.datetime(1968, 10, 24, 0, 0): [{'performer': 'Dave Davis', 'source': 'The Montgomery, Alabama Montgomery Advertiser, October 24, 1968, 8'}], datetime.datetime(1968, 10, 25, 0, 0): [{'performer': 'Dave Davis', 'source': 'Alabama Journal (Montgomery, Alabama), October 25, 1968, 10'}], datetime.datetime(1968, 10, 26, 0, 0): [{'performer': 'Dave Davis', 'source': 'The Montgomery, Alabama Montgomery Advertiser, October 26, 1968, 11'}]}
# {datetime.datetime(1968, 10, 21, 0, 0): [{'performer': 'Dave Davis', 'source': 'Alabama Journal (Montgomery, Alabama), October 21, 1968, 11'}], datetime.datetime(1968, 10, 22, 0, 0): [{'performer': 'Dave Davis', 'source': 'The Montgomery, Alabama Montgomery Advertiser, October 22, 1968, 16'}], datetime.datetime(1968, 10, 24, 0, 0): [{'performer': 'Dave Davis', 'source': 'The Montgomery, Alabama Montgomery Advertiser, October 24, 1968, 8'}], datetime.datetime(1968, 10, 25, 0, 0): [{'performer': 'Dave Davis', 'source': 'Alabama Journal (Montgomery, Alabama), October 25, 1968, 10'}], datetime.datetime(1968, 10, 26, 0, 0): [{'performer': 'Dave Davis', 'source': 'The Montgomery, Alabama Montgomery Advertiser, October 26, 1968, 11'}]}
# {datetime.datetime(1968, 10, 21, 0, 0): [{'performer': 'Dave Davis', 'source': 'Alabama Journal (Montgomery, Alabama), October 21, 1968, 11'}], datetime.datetime(1968, 10, 22, 0, 0): [{'performer': 'Dave Davis', 'source': 'The Montgomery, Alabama Montgomery Advertiser, October 22, 1968, 16'}], datetime.datetime(1968, 10, 24, 0, 0): [{'performer': 'Dave Davis', 'source': 'The Montgomery, Alabama Montgomery Advertiser, October 24, 1968, 8'}], datetime.datetime(1968, 10, 25, 0, 0): [{'performer': 'Dave Davis', 'source': 'Alabama Journal (Montgomery, Alabama), October 25, 1968, 10'}], datetime.datetime(1968, 10, 26, 0, 0): [{'performer': 'Dave Davis', 'source': 'The Montgomery, Alabama Montgomery Advertiser, October 26, 1968, 11'}]}
# {datetime.datetime(1968, 10, 21, 0, 0): [{'performer': 'Dave Davis', 'source': 'Alabama Journal (Montgomery, Alabama), October 21, 1968, 11'}], datetime.datetime(1968, 10, 22, 0, 0): [{'performer': 'Dave Davis', 'source': 'The Montgomery, Alabama Montgomery Advertiser, October 22, 1968, 16'}], datetime.datetime(1968, 10, 24, 0, 0): [{'performer': 'Dave Davis', 'source': 'The Montgomery, Alabama Montgomery Advertiser, October 24, 1968, 8'}], datetime.datetime(1968, 10, 25, 0, 0): [{'performer': 'Dave Davis', 'source': 'Alabama Journal (Montgomery, Alabama), October 25, 1968, 10'}], datetime.datetime(1968, 10, 26, 0, 0): [{'performer': 'Dave Davis', 'source': 'The Montgomery, Alabama Montgomery Advertiser, October 26, 1968, 11'}]}
# {datetime.datetime(1968, 10, 21, 0, 0): [{'performer': 'Dave Davis', 'source': 'Alabama Journal (Montgomery, Alabama), October 21, 1968, 11'}], datetime.datetime(1968, 10, 22, 0, 0): [{'performer': 'Dave Davis', 'source': 'The Montgomery, Alabama Montgomery Advertiser, October 22, 1968, 16'}], datetime.datetime(1968, 10, 24, 0, 0): [{'performer': 'Dave Davis', 'source': 'The Montgomery, Alabama Montgomery Advertiser, October 24, 1968, 8'}], datetime.datetime(1968, 10, 25, 0, 0): [{'performer': 'Dave Davis', 'source': 'Alabama Journal (Montgomery, Alabama), October 25, 1968, 10'}], datetime.datetime(1968, 10, 26, 0, 0): [{'performer': 'Dave Davis', 'source': 'The Montgomery, Alabama Montgomery Advertiser, October 26, 1968, 11'}]}
# Redwood Inn
# {datetime.datetime(1969, 9, 17, 0, 0): [{'performer': 'Candace', 'source': 'Variety, September 17, 1969, 51'}]}
# Riversize Plaza
# {datetime.datetime(1970, 6, 30, 0, 0): [{'performer': 'Pudgy Roberts', 'source': 'UTC50'}]}
# Purple Onion
# {datetime.datetime(1970, 6, 30, 0, 0): [{'performer': 'Pudgy Roberts', 'source': 'UTC50'}]}
# Flamingo
# {datetime.datetime(1970, 11, 18, 0, 0): [{'performer': 'Jim Bailey', 'source': 'Chatter: Las Vegas Duke, Forrest., Variety, 261, no. 1, November 18, 1970, 85'}]}
# Carnegie Hall
# {datetime.datetime(1971, 1, 27, 0, 0): [{'performer': 'Lynne Carter', 'source': 'One-Man Show: Lynne Carter, Sege., Variety, 261, no. 11, January 27, 1971, 50'}]}
# {datetime.datetime(1973, 5, 30, 0, 0): [{'performer': 'Jim Bailey', 'source': 'Music Records: Bailey SRO 17G, N.Y, Variety, 271, no. 3, May 30, 1973, 57'}]}
# Leonarda's
# {datetime.datetime(1972, 4, 1, 0, 0): [{'performer': 'LaVerne Cummings', 'source': 'cummingsBAR.jpg'}]}
# Fairmont Hotel (San Francisco)
# {datetime.datetime(1973, 5, 30, 0, 0): [{'performer': 'Jim Bailey', 'source': 'Music Records: Bailey SRO 17G, N.Y, Variety, 271, no. 3, May 30, 1973, 57'}]}
# Isle of Capri
# {datetime.datetime(1975, 10, 30, 0, 0): [{'performer': 'Jill Christie', 'source': 'stevens-stacy-10-30-75.jpg'}, {'performer': 'Marsha Michaels', 'source': 'stevens-stacy-10-30-75.jpg'}, {'performer': 'Stacy Stevens', 'source': 'stevens-stacy-10-30-75.jpg'}]}
# {datetime.datetime(1975, 10, 30, 0, 0): [{'performer': 'Jill Christie', 'source': 'stevens-stacy-10-30-75.jpg'}, {'performer': 'Marsha Michaels', 'source': 'stevens-stacy-10-30-75.jpg'}, {'performer': 'Stacy Stevens', 'source': 'stevens-stacy-10-30-75.jpg'}]}
# {datetime.datetime(1975, 10, 30, 0, 0): [{'performer': 'Jill Christie', 'source': 'stevens-stacy-10-30-75.jpg'}, {'performer': 'Marsha Michaels', 'source': 'stevens-stacy-10-30-75.jpg'}, {'performer': 'Stacy Stevens', 'source': 'stevens-stacy-10-30-75.jpg'}]}
# Vive Paris Veve at Flamingo
# {datetime.datetime(1975, 11, 5, 0, 0): [{'performer': 'Sahdji', 'source': 'Night Club Reviews: Flamingo. Las Vegas Duke., Variety, 280, no. 13, November 5, 1975, 75'}]}
# Little Hippodrome
# {datetime.datetime(1975, 12, 17, 0, 0): [{'performer': 'Lynne Carter', 'source': 'Night Club Reviews: Little Hippodrome, N.Y. Jose., Variety, 281, no. 6, December 17, 1975, 60'}]}
# La Cage Aux Folles
# {datetime.datetime(1982, 12, 15, 0, 0): [{'performer': 'Christopher Bridgeman', 'source': 'New Acts: CHRISTOPHER BRIDGEMAN Kirk., Variety, 309, no. 7, December 15, 1982, 83'}]}
# Inner Circle
# {datetime.datetime(1983, 11, 25, 0, 0): [{'performer': 'Lynne Carter', 'source': 'Spotlight on Nigh Spots Sommers, Michael. Back Stage 24, no. 46, November 25, 1983, 70'}]}
# Gardenia
# {datetime.datetime(1984, 3, 28, 0, 0): [{'performer': 'Kenny Sacha', 'source': 'Night Club Reviews: Gardenia, L.A. Kirk., Variety, 314, no. 9, March 28, 1984, 101'}]}
# Harrah's Tahoe (Lake Tahoe)
# {datetime.datetime(1984, 6, 27, 0, 0): [{'performer': 'Julie Dees', 'source': "Night Club Reviews: Harrah's Tahoe Shie., Variety, 315, no. 9, June 27, 1984, 79"}]}
# Mayfair Theater
# {datetime.datetime(1985, 8, 7, 0, 0): [{'performer': 'Charles Pierce', 'source': 'Legitimate: Legit Chatter In The Wings, Variety, 320, no. 2, August 7, 1985, 78, 82'}]}
# Not A Well Woman, at Henry Fonda Theater
# {datetime.datetime(1986, 11, 19, 0, 0): [{'performer': 'Charles Pierce', 'source': 'One-Man Show: Charles Pierce: Not A Well Woman CART., Variety, 325, no. 4, November 19, 1986, 93'}]}
# Tara Club
# {datetime.datetime(1986, 12, 17, 0, 0): [{'performer': 'Champagne', 'source': 'Night Club Reviews: Tara Club, Downingtown, Pa. Hari., Variety, 325, no. 8, December 17, 1986, 88'}, {'performer': 'Dora Jar', 'source': 'Night Club Reviews: Tara Club, Downingtown, Pa. Hari., Variety, 325, no. 8, December 17, 1986, 88'}, {'performer': 'Lori La Rue', 'source': 'Night Club Reviews: Tara Club, Downingtown, Pa. Hari., Variety, 325, no. 8, December 17, 1986, 88'}, {'performer': 'Crystal Lane', 'source': 'Night Club Reviews: Tara Club, Downingtown, Pa. Hari., Variety, 325, no. 8, December 17, 1986, 88'}, {'performer': 'Monica Rey', 'source': 'Night Club Reviews: Tara Club, Downingtown, Pa. Hari., Variety, 325, no. 8, December 17, 1986, 88'}]}
# {datetime.datetime(1986, 12, 17, 0, 0): [{'performer': 'Champagne', 'source': 'Night Club Reviews: Tara Club, Downingtown, Pa. Hari., Variety, 325, no. 8, December 17, 1986, 88'}, {'performer': 'Dora Jar', 'source': 'Night Club Reviews: Tara Club, Downingtown, Pa. Hari., Variety, 325, no. 8, December 17, 1986, 88'}, {'performer': 'Lori La Rue', 'source': 'Night Club Reviews: Tara Club, Downingtown, Pa. Hari., Variety, 325, no. 8, December 17, 1986, 88'}, {'performer': 'Crystal Lane', 'source': 'Night Club Reviews: Tara Club, Downingtown, Pa. Hari., Variety, 325, no. 8, December 17, 1986, 88'}, {'performer': 'Monica Rey', 'source': 'Night Club Reviews: Tara Club, Downingtown, Pa. Hari., Variety, 325, no. 8, December 17, 1986, 88'}]}
# {datetime.datetime(1986, 12, 17, 0, 0): [{'performer': 'Champagne', 'source': 'Night Club Reviews: Tara Club, Downingtown, Pa. Hari., Variety, 325, no. 8, December 17, 1986, 88'}, {'performer': 'Dora Jar', 'source': 'Night Club Reviews: Tara Club, Downingtown, Pa. Hari., Variety, 325, no. 8, December 17, 1986, 88'}, {'performer': 'Lori La Rue', 'source': 'Night Club Reviews: Tara Club, Downingtown, Pa. Hari., Variety, 325, no. 8, December 17, 1986, 88'}, {'performer': 'Crystal Lane', 'source': 'Night Club Reviews: Tara Club, Downingtown, Pa. Hari., Variety, 325, no. 8, December 17, 1986, 88'}, {'performer': 'Monica Rey', 'source': 'Night Club Reviews: Tara Club, Downingtown, Pa. Hari., Variety, 325, no. 8, December 17, 1986, 88'}]}
# {datetime.datetime(1986, 12, 17, 0, 0): [{'performer': 'Champagne', 'source': 'Night Club Reviews: Tara Club, Downingtown, Pa. Hari., Variety, 325, no. 8, December 17, 1986, 88'}, {'performer': 'Dora Jar', 'source': 'Night Club Reviews: Tara Club, Downingtown, Pa. Hari., Variety, 325, no. 8, December 17, 1986, 88'}, {'performer': 'Lori La Rue', 'source': 'Night Club Reviews: Tara Club, Downingtown, Pa. Hari., Variety, 325, no. 8, December 17, 1986, 88'}, {'performer': 'Crystal Lane', 'source': 'Night Club Reviews: Tara Club, Downingtown, Pa. Hari., Variety, 325, no. 8, December 17, 1986, 88'}, {'performer': 'Monica Rey', 'source': 'Night Club Reviews: Tara Club, Downingtown, Pa. Hari., Variety, 325, no. 8, December 17, 1986, 88'}]}
# {datetime.datetime(1986, 12, 17, 0, 0): [{'performer': 'Champagne', 'source': 'Night Club Reviews: Tara Club, Downingtown, Pa. Hari., Variety, 325, no. 8, December 17, 1986, 88'}, {'performer': 'Dora Jar', 'source': 'Night Club Reviews: Tara Club, Downingtown, Pa. Hari., Variety, 325, no. 8, December 17, 1986, 88'}, {'performer': 'Lori La Rue', 'source': 'Night Club Reviews: Tara Club, Downingtown, Pa. Hari., Variety, 325, no. 8, December 17, 1986, 88'}, {'performer': 'Crystal Lane', 'source': 'Night Club Reviews: Tara Club, Downingtown, Pa. Hari., Variety, 325, no. 8, December 17, 1986, 88'}, {'performer': 'Monica Rey', 'source': 'Night Club Reviews: Tara Club, Downingtown, Pa. Hari., Variety, 325, no. 8, December 17, 1986, 88'}]}
# Theater East
# {datetime.datetime(1988, 10, 5, 0, 0): [{'performer': 'Craig Russell', 'source': "Forbidden' A Boxoffice Hit Off-Broadway; Spoof Revue Seen As A Perennial In N.Y. Hummler, Richard., Variety, 332, no. 11, October 5, 1988, 147"}]}
# Orpheum Theater
# {datetime.datetime(1989, 8, 2, 0, 0): [{'performer': 'Charles Busch', 'source': "OFF-B'WAY REVIEW - The Ladv In Question Humm., Variety, 336, no. 3, August 2, 1989, 78"}]}
# New Theatre
# Kemble?
# (Pantages circuit)
# (Orpheum circuit)

# %%
large_g = nx.DiGraph()

for venue, d in venue_data.items():
    small_g = None
    for date, datapoints in d['full_dates'].items():
        edge_data = {
            'venue': venue,
            'date': date.strftime('%Y-%m-%d')
        }

        performers = list(set([data['performer'] for data in datapoints]))
        attrs = {}
        if len(performers) > 1:
            small_g = nx.complete_graph(performers)
            for edge in small_g.edges:
                attrs[edge] = edge_data
            nx.set_edge_attributes(small_g, attrs)
    if small_g:
        attrs = {}
        for edge in small_g.edges:
            if large_g.has_edge(edge[0], edge[1]):
                large_g.edges[edge[0], edge[1]]['sources'].append(edge_data)
                large_g.edges[edge[0], edge[1]]['weight'] += 1
            else:
                large_g.add_edge(edge[0], edge[1])
                attrs[edge] = {'sources': [edge_data], 'weight': 1}
        nx.set_edge_attributes(large_g, attrs)

# %%
attrs = {}
export_g = nx.DiGraph()
for edge in large_g.edges:
    min_date = None
    max_date = None
    for source in large_g.edges[edge]['sources']:
        date = datetime.strptime(source['date'], '%Y-%m-%d')
        if not min_date:
            min_date = date
        if not max_date:
            max_date = date
        if date > max_date:
            max_date = date
        if date < min_date:
            min_date = date
    attrs[edge] = {
        'min_date': min_date.strftime('%Y-%m-%d'),
        'max_date': max_date.strftime('%Y-%m-%d'),
        'weight': large_g.edges[edge]['weight']
    }
    export_g.add_edge(edge[0], edge[1], **attrs[edge])

# %%
nx.write_gexf(export_g, 'relations.gexf')

# %%
## Task: create chains of dates through iterations of them

DAYS = 7

diff = timedelta(days=DAYS)

start_date = datetime(1931, 1, 15, 0, 0)
test_list = [
    datetime(1931, 1, 15, 0, 0),
    datetime(1930, 1, 15, 0, 0),
    datetime(1929, 1, 15, 0, 0),
    datetime(1930, 12, 15, 0, 0),
    datetime(1930, 12, 30, 0, 0),
    datetime(1931, 1, 17, 0, 0),
    datetime(1931, 1, 19, 0, 0),
    datetime(1931, 1, 21, 0, 0),
    datetime(1931, 1, 26, 0, 0),
    datetime(1931, 1, 10, 0, 0),
    datetime(1931, 1, 5, 0, 0),
    datetime(1931, 2, 1, 0, 0),
    datetime(1931, 3, 1, 0, 0),
    datetime(1931, 6, 1, 0, 0),
    datetime(1931, 7, 1, 0, 0)
]


def create_chain_of_dates(start_date=datetime.now(), datelist=[datetime.now()], diff=timedelta(days=7)):
    """ Returns a list of dates that are chained (3 iterations down) """
    captured_dates, more_dates = [], True

    range_start = start_date - diff
    range_end = start_date + diff

    # Will search for dates in the range from {range_start} to {range_end}

    while more_dates:
        dates_within_range = [date for date in datelist if date > range_start and date < range_end]
        captured_dates.extend(dates_within_range)

        for date in dates_within_range:
            start_date = date

            range_start = start_date + timedelta(days=-DAYS)
            range_end = start_date + timedelta(days=DAYS)

            # Will search for dates in the range from {range_start} to {range_end}

            dates_within_range = [date for date in datelist if date > range_start and date < range_end]

            for date in dates_within_range:
                start_date = date

                range_start = start_date + timedelta(days=-DAYS)
                range_end = start_date + timedelta(days=DAYS)

                # Will search for dates in the range from {range_start} to {range_end}

                dates_within_range = [date for date in datelist if date > range_start and date < range_end]

                captured_dates.extend(dates_within_range)

            captured_dates.extend(dates_within_range)
        before = len(captured_dates)
        captured_dates = list(set(captured_dates))
        more_dates = (len(captured_dates) - before) > 0
        # print(more_dates)

    return sorted(captured_dates)

create_chain_of_dates(start_date=start_date, datelist=test_list, diff=diff)
# Out:
# [datetime.datetime(1930, 12, 30, 0, 0),
#  datetime.datetime(1931, 1, 5, 0, 0),
#  datetime.datetime(1931, 1, 10, 0, 0),
#  datetime.datetime(1931, 1, 15, 0, 0),
#  datetime.datetime(1931, 1, 17, 0, 0),
#  datetime.datetime(1931, 1, 19, 0, 0),
#  datetime.datetime(1931, 1, 21, 0, 0),
#  datetime.datetime(1931, 1, 26, 0, 0),
#  datetime.datetime(1931, 2, 1, 0, 0)]

# %%
periods = {}
MIN_YEAR = 1930
MAX_YEAR = 1945

for venue in venue_data:
    periods[venue] = {}
    for date in sorted([x for x in venue_data[venue]['full_dates'].keys()]):
        if date.year > MAX_YEAR or date.year < MIN_YEAR:
            # print(f'sorting out {date.year}')
            continue
            
        # print(f'...ok {date.year}')
        if not date.year in periods[venue]:
            periods[venue][date.year] = {}
        if not date.month in periods[venue][date.year]:
            periods[venue][date.year][date.month] = {}

        for datapoint in venue_data[venue]['full_dates'][date]:
            if not datapoint['performer'] in periods[venue][date.year][date.month]:
                periods[venue][date.year][date.month][datapoint['performer']] = {'counter': 0}
            periods[venue][date.year][date.month][datapoint['performer']]['counter'] += 1

# %%
# create network

G = nx.DiGraph()

for venue, _ in periods.items():
    for year, _ in _.items():
        for month, _ in _.items():
            for edge in nx.complete_graph([x for x in _.keys()]).edges:
                # edge1
                G.add_edge(edge[0], edge[1], weight=_[edge[0]]['counter'])
                G.add_edge(edge[1], edge[0], weight=_[edge[1]]['counter'])

# %%
nx.write_gexf(G, 'relations-in-time.gexf')

# %%
comments = {}

for ix, row in df.iterrows():
    if row['Unsure whether drag artist'] or row['Exclude from visualization']:
        continue
        
    if row['Comment on node: performer']:
        if row['Performer first-name'] and row['Performer last-name']:
            performer = row['Performer first-name'] + ' ' + row['Performer last-name']
        elif row['Normalized performer']:
            performer = row['Normalized performer']
        elif row['Performer']:
            performer = row['Performer']
        else:
            print('ERROR')
            
        if not performer in comments:
            comments[performer] = []
        
        comment = row['Comment on node: performer'].strip()
        if not comment in comments[performer]:
            comments[performer].append(comment)

comments
# Out:
# {'Pepper Cortez': ["Opener for women's wrestling match!"],
#  'Gene Dana': ["Opener for women's wrestling match!",
#   'warbled Shanghai Flo and seemed to be well liked by the customers'],
#  'Neil Dornay': ["Opener for women's wrestling match!",
#   'credited as "exotic dancer"'],
#  'Rhodie Kinsella': ['arrested'],
#  '— Rocky': ['dressed as girls, are daintier than any of the back stars.',
#   'unclear if performing in drag here'],
#  'Billy Rohmer': ["Opener for women's wrestling match!"],
#  'Jackie Collier': ['an imitator of Barbette!'],
#  'Sepia Mae West —': ['"An important night club note that should have been recorded before now is that Mae West, the creole fashion plate, one of the foremost female impersonators of the present time, is headlining at the 1-0-1 Club in West 139th street. Probably one of the reason [sic] Impresario MacDonald will have to enlarge his emporium to accommodate his overflow patronage."',
#   '"returned to the city last week and will be seen nightly . . . Big Ivy, owner of the place, plans a public welcome for his star who returned with three trunks of the latest creations in gowns."',
#   '"\'Mae\' Looks like anything but a member of the puzzle sex." "At present he em-cees for the Cabin Inn and the crowds come nightly. Whether in male clothes or slinky velvet gowns with tinted toenails he offers a tonic for jaded diners and dancers."',
#   '"Had a nice long visit from that clever female impersonator, . . . Dickie is just back from the coast after making a few weeks on the lots of Hollywood, at present is arranging for a hurried return trip only giving his old friends a few days to enjoy his congenial company."',
#   '"Brown Mae West"',
#   '"headline attraction"',
#   '"special performance at the Fourth of July dance"',
#   '"He tells me that he has gone into this art purely from an artistic standpoint. Personally, I think that he has made a good job of it."',
#   'producer!',
#   '"struck and killed an unidentified man" "Barrows was released."'],
#  'Clarenz Henderson': ['"Leroy McDonald, proprietor of the 1-0-1 Club, is peeved at a local (out of town) paper for what it had to say concerning the late Clarenz who has an em-cee at the Harlem \'hot\' spot. CLarenz . . . according to McDonald, did not leave any mash notes addressed to anyone before jumping."',
#   'Washington DC-based'],
#  'Jayette —': ['"Sensational Dance Stylist"'],
#  'Unnamed performer hissed off stage —': ['"a female impersonator was hissed off the stage"'],
#  'Ray Shannon': ['"For laughs Shannon goes femme impersonator, but the talk is none too strong."',
#   'sub as female impersonator'],
#  'Bobby Allen': ['"Dance of Death"',
#   '"Premiere Danscanse"',
#   '"The Tragedian of Dance"',
#   'premier danseuse',
#   '"The Tragedienne of Dance"',
#   '"Oriental"',
#   'character dancer; "Billy Allen" but guessing that this is the same Bobby Allen that appeared two weeks later.'],
#  'Flo Arden': ['"Sandysky\'s Kate Smith"'],
#  'Princess Diane': ['"in Her Powder Puff Dance"'],
#  'George Hayes': ['MC'],
#  'Jackie Lane': ['"Russian Whirlwind"',
#   '"Prima Donna"',
#   'MC',
#   'MC; "Formerly Starred Clayton-Jackson-Durante Trio of B\'way Fame"'],
#  'Doyle Mack': ['"Comedian"'],
#  'Irvin Mazzie': ['MC'],
#  'Kit ("Titanic") Russell': ['"Female Impersonator Extraordinary"',
#   '"Tallest of the Show Boys"',
#   'Featured with picture',
#   '"Titanic, tallest of the showboys, is beheld over for a fourth week."',
#   '"handsomest and tallest of the New York showboys"',
#   '"opened his ninth week as a headliner in the New Look Club\'s \'Gay Boy Revue.\' Known as the \'tallest of the showboys,\' Titanic is recognized as one fo the outstanding female impersonators. His delivery of songs is of the Mae West school and he has the same throaty voice."',
#   'Featured in image.',
#   'From Uniontown, PA'],
#  'Paul Russell': ['"MALE GYPSY ROSE LEE . . . Also the Most Outstanding Female Impersonator in the Country" -- interesting gendering: "She\'s Terrific"!',
#   '"King of the Marinettes" - featuring image!',
#   '"King of the Marionettes"'],
#  'Jackie Starr': ['"The original male impersonator of the world famous Gypsie Rose Lee"',
#   '"Male Gypsy Rose Lee"'],
#  'Rae Bourbon': ['working in drag',
#   'Called "Jean Malin\'s successor" in promotional material',
#   'unclear if he was in drag',
#   'His role is called "a Nance dressmaker . . . He may be the year\'s discovery."',
#   'Played Bowery Rose, a "fem Bowery shoplifter," reviewed as "a rich bit"',
#   'something really worth while in the theater . . . Has no superior at pantomime.',
#   '8 week contract',
#   'unclear if he was performing in drag here but his performance is called "delicate ditties"',
#   'five years here',
#   'routines "Pocahontas," "Tepee for Two" and "Fortune Teller"',
#   'has been associated with local niteries for some time',
#   '"was added to the show to bring in the night club crowd . . Using double entendre material"',
#   'new to the Angel and this zany comedian with the soprano hips is better than Jean Malin was in his heyday.',
#   'Called "West Coast comic" - and a "smooth, fat guy" who carries the "laugh load." He does female impersonators, unsure whether he was in drag',
#   'holding the spotlight for over a half-hour with a routine of original yrics and take-offs of the fems. . . . reaches way down in gutter for good portion of his material.',
#   'Alongside Rosita, "Dance of the Hands"; definitely appearing; in drag',
#   'Appeared in the Mexicana Room, "with his gay songs and gay stories"',
#   'Arrested "wearing the clothes of the opposite sex"',
#   'told Judge . . . that he was a paid performer . . . and had not appeared on the street in female attire.',
#   'first show after sex change',
#   'arrested last night . . . in her bow at the Melody Room here on a charge of impersonating a woman.',
#   'arrested for being "A male entertainer dressed in woman\'s clothing doing an alleged lewd dance."',
#   'Direct from The French Quarter in New Orleans',
#   '"recently became a female (via surgery), has a 10-karat engagement ring from his September groom-to-be."',
#   'Bourbon is top-billed and publicizing the show under same name as in west coast town.',
#   'Name not actually mentioned; "found . . . guilty of staging an indecent show"',
#   'came here recently from New York',
#   'also performed under "Birmingham Berta"?',
#   'Unclear whether this was in Matawan, NJ?',
#   'modeling new dresses, ensembles, and coats.'],
#  'Unnamed tall, black performer —': ['"Visiting celebrities supply most of the entertainment, supplemented by a four-piece band and a tall, coal-black Negro who is one of those erotic phenomena called \'queens\'—female impersonators. This one has assumed the name of a famous white movie star, wears a wig and an evening gown, and sings alto."'],
#  'Unnamed fan dancer in Philadelphia —': ['"Music blared, a fan dancer swished her fans. Two hundred patrons of a night club were watching the show. Suddenly a score of policement rushed into the club and arrested the dancer and the proprietor. The officers found the fan dancer was a female impersonator."'],
#  'Gene Baye': ['"The Nightingale Singer',
#   '"Uproarious Comedian"',
#   '"The Male Lily Pons"'],
#  'Francis Bouche': ['"Blues Singer"'],
#  'Gene Casali': ['"That Boy Cleopatra in the Dance of the Cobra"',
#   '"Toe and Oriental Dancer"',
#   '"in an oriental dance"',
#   '"in an Oriental Balad Dance"'],
#  'Jerry Clayton': ['MC', '"Sensation New M. C."'],
#  'Jerry Francis': ['"The Male Peggy Hopkins Joyce"',
#   '"Male Peggy Hopkins Joyce"'],
#  'Bobby Hayes': ['"Featured in His Dance Interpretations"',
#   '"A Dancing Doll"',
#   '"Dresden Dancing Doll"'],
#  'Johnny Kaye': ['"The Boy Who Has Completely Captivated Syracuse"',
#   '"International Star—Outstanding Fashion Plate"',
#   '"Emm-See and Hot-Cha Singer"'],
#  'Jean Marlow': ['"That Beautiful Platinum Blonde Songstress"',
#   '"Sophisticated Songster"'],
#  'Merry Pickford': ['"The Male Sally Rand Fan Dancer in New and Original Dance Creations"',
#   '"the Male Sally Rand"',
#   '"Male Sally Rand Fan Dancer"',
#   '"THE MALE SALLY RAND Dancing Her FAN and BUBBLE Dance"',
#   'male Sally Rand',
#   'from Canada?!'],
#  'Bonnie Clark': ['"one of the greatest female impersonators is now with WPA\'s \'Living Newspaper\' at the Biltmore"'],
#  'Jack Caruso': ['Name corroborated by 1935-07 Times Union,  23 Jul 1935, p. 15 i2'],
#  'Cardie Woodie': ['"Cardie Woodie and His Orchestra"'],
#  'Sepia Gloria Swanson —': ['"For years Gloria has been one of the outstanding floor show personalities and in his latest role as headliner at the Britwood, the impersonator\'s work is supreme."',
#   'Dead at 33 years old.',
#   'Dead after a year of illness. Born in Atlanta, moved to Chicago at an early age. Said to have started "the vogue for adopting the names of noted women in the entertainment world. He was also said to have been one of the first to adopt feminine dress entirely, and was often seen in gorgeous evening gowns, costly furs, high heel shoes, etc."',
#   'Dead. The column makes it sound like Swanson died in a train wreck but in actuality from disease.',
#   'appeared with Bobbie Howell, female saxophonist'],
#  'Bobbie Davis': ['Called a "creole \'songbird\'," using scare quotes, perhaps to point out her queerness.',
#   'Bobbie Davis described as a girl with a "pleasuing personality" and "nimble feet."',
#   '"starring in renditions of up-to-date hit songs, is a songstress worthy of commendation."'],
#  'Valda Gray': ['"female impersonator and producer of the show"',
#   '"has a flare of finales at the Cabin Inn"',
#   '"Valda Gray, once more excels in the masterful presentation of \'her\' latest floor show \'Swingin\' at the Cabin Inn\' which features those famous impersonators."',
#   'She used as gender pronoun (and no indication of her being a female impersonator...?).',
#   'described here as one of "leading impersonators" of the city.',
#   '"show is produced by"',
#   '"Emceeing the show"',
#   '"Sunday night concluded a long term stand for Valda Grays\' [sic] Show which for the past number of years has been produced by the very capable Valda Gray, the Valda Gray show will open at the quite popular Ritz Lounge"',
#   '"[Francis Dee =] that classy female impersonator . . . formerly a feature with Valda Grey\'s Cabin Inn revue."'],
#  'Peaches Browning': ['"featured in a torrid scene, \'Turn On That Red Hot Heat\'"'],
#  'Joe Hart': ['"the newest lyric tenor who thrills with a swell repertoire of popular songs"'],
#  'Herman Ferdinand': ['"the able master of ceremonies"'],
#  'Nina Mae McKinney': ['Nina Mae McKinney is the correct name as per The Chicago Defender 14 Aug 1937, 9.'],
#  'Alice White': ['Only called White here but Alice White is corroborated in The Chicago Defender 26 Aug 1939, 21.',
#   '"talented female impersonator, has surpassed \'her\' previous record as a producer."'],
#  'Lyle Page': ['"Legerdemain"??',
#   'MC',
#   '"in His Passion and Thrilling Persian Dance"',
#   "While Lyle Page is not used in the ad, Syracuse Journal, April 19, 1935, 37 (b) corroborates Lyle Page's name"],
#  'Lucian —': ['"Lucian, who refuses to disclose his real name, today said he and his \'boys\' were waiting final word from Michaels as to whether it would be possible to continue their show at the nightclub. Michaels, however, has apparently abandoned his fight against Sheriff Malley, who ordered the show closed. The Chateau maestro has not talked with Lucian since Tuesday. Asked if he had settled terms of his contract with Michaels, which is said to run to July 1, Lucian replied: \'He\'ll take care of that, all right, he is a fine man.\' \'I\'m not interested in the contract at all,\' he said, \'I\'m more concerned at leaving town with a clean record. If I don\'t hear from Michaels today, I\'m going to take my boys to New York tomorrow, where we have an engagement.\' Sheriff Malley, who ordered the show to stop after last Saturday\'s performance, today said the case was closed as far as he was concerned. Public Safety Commissioner Walter P. Cox today again stated he had received no complaints about the playboys who are staying at a downtown hotel. He said he was \'not looking for trouble\' and that no steps would be taken unless complaints are received about the troupe."',
#   '"wry quips with ringsiders"; "male Sophie Tucker";',
#   '"The Male Sophie Tucker"; "Last of the Red Hot Papas"',
#   '"The Voice In a Million"'],
#  'Mother/Sepia Marlene Smother/Dietrich': ['"Joe is a well-seasoned performer. Besides singing and dancing very well, he has youth and loads of personality."',
#   '"inimitable female impersonator and dancing parody-singer, Joe Smothers, who had the throng in a snappy mood during his renditions."',
#   '"One of the larger of the New York nite spots was going to offer \'Mother Smothers,\' of Baltimore fame, a juicy amount of what it takes for coffee and cakes, but no can do now because of the police warning to all New York nite spot owners about hiring female impersonators. One of the funniest cartoons in the current edition of Esquire is by E. Simms Campbell, with the caption: \'And remember, none of that hi-de- do stuff."'],
#  'Manhattan Paul': ['"A new entertainer from the East . . . a versatile female impersonator from New York City and Pittsburgh. This artist who has already been introduced in a four week\'s engagement at the Chocolate Bar, sings in Russian, Jewish, and features toe-dancing, and has already won much generous local applause."'],
#  'Jean Malin': ['misspelled as "Jean Mallin"',
#   'takes up about half of the floor show time with his femme impersonations',
#   'giving an impersonation of Aimee Semple McPherson that is something',
#   '"Jean Malin\'s burlesque radio number is one of the high spots of the new show at the Club Richman"',
#   '"Billy Bryant, who came to town as a legendary show-boat figure of the Ohio and Mississippi, winds up in night club—and in the same show, at the Club Richman, is that wise cracking effeminate master-of-ceremonies, Jean Malin . . . Yes, Broadway makes strange floorshow fellows."',
#   '". . . Jean Malin is the chief attraction for the naughtic clan."',
#   '"Most of his spare time in the [Belasco] theatre was utilized by him to sew dresses for the soirees at Rockland Palace, the Harlem Casino and other spots of that type. Dressed as a woman, Malin was a consistent winner of first prizes in these contests."',
#   'His age corroborated from http://sfbaytimes.com/jean-malin-broadways-queen-of-queens-2/'],
#  'Dixie Dixon': ['MC', 'emsee'],
#  'Funny Fanny': ['mc + comedienne', '"Cavalcade of Laughs"'],
#  'Jud King': ['"Fast Tap Dancer"'],
#  'Mickey Nelson': ['"Classical Tap Dancer"',
#   '"Classical Tap Dance"',
#   '"Personality Boy"'],
#  'Guilda —': ['billed as French Marlene Dietrich, keeps illusion going until finale when he doffs blond wig for added mitts.',
#   'Is Guilda the Gilda that was charged of "indecent performance" in Ottawa, see Strip \'Gilda\' of Gender in Hull Obscenity Ran Variety 225, no. 3, December 13, 1961, 51/'],
#  '— Tangara': ['"Bombshell of Rhythm"',
#   '"That Bombshell of Rhythm"',
#   '"Exotic Personality of the Dance"'],
#  'Louis Diggs': ['"Queen of Female Impersonators"',
#   '"well known and popular Washington cabaret entertainer and female impersonator, who has been able to fool thousands of night club patrons on his sexual identity, but could not fool Uncle Sam who called him in the draft. Louis will have to trim his locks and discard his powder puff for a rifle.:"',
#   '"A group of female impersonators, featuring Louis Diggs, gave a boatride on the Robert E. Lee the other night."'],
#  'Arthur Budd': ['Also known as Rosebud, according to 1930-09-20 Daily News, 22'],
#  'Louis Edelstein': ['unclear if pansy performer/in drag'],
#  'Peggy Joyce': ['"Peggy Hopkins Joyce"',
#   '"did the \'ladies\' show off. Everything was all right until \'Peg\'s shoulder strap broke."',
#   '"sensational"'],
#  'Leo the Lion —': ['"A pipsqueak of a fellow . . . gives hilarious froth to the \'Gay Boy Revue\' . . . Leo emerges, a shy, unpretty lass, and proceeds to give the mos mischievous twists to the drabest of lyrics. Then he climaxes his bit with a startling exhibition of boogie-woogie music. An outstanding comic of the nervous, athletic school."; legal name comes from 1948-07-21 The Cincinnati Enquirer (Cincinnati, Ohio)21 Jul 1948, WedPage 14',
#   '"The strangest professional name in show business now shines in the foyer marquee of the New Look Club . . . It belongs to Leo the Lion, New York-born female impersonator, comic and boogie-woogie pianist now featured in the Gay Boy Revue. \'Leo the Lion\' is not his real name, of course. He signs his contracts and checks \'Leon the Lion.\' The latter name was legalized in Federal Court a year ago."'],
#  'Danny Brown': ['"returns this week as master of ceremonies after being absent the last two weeks due to illness."',
#   'MC?'],
#  'Jean La Monte': ['"formerly . . . a member of the international dance team of Corday and La Monte, which appeared at the World\'s Fair in Chicago."',
#   'With picture!',
#   '"clever toe dancer who, besides doing his own specialty, leads the boys of the ensemble in routines."',
#   '"Singing M.C."',
#   '"Gene LaMonte is featured in Karyl Norman\'s all-male revue at the Club Frontenac this week and leads off the twenty-act show with a dance version of the song that made Vincent Lopez famous, the lilting \'Nola.\' LaMonte also performs his impression of the dances done Betty Hutton, Detroit\'s number-one jitterbug. He first became well known to Detroiters through his orchestra, Gene LaMonte\'s Syncopators, before he studied dancing under Ned Wayburn, and began making interpretative and comedy dances his forte."',
#   '"Sensational Toe Dancer"',
#   '"Marvelous Toe Dancer and Singer"',
#   '"Sensational Toe Dancer—Direct from Club Florida, New York—Also Starred with Fachon & Marco"',
#   '"Dancer Extraordinary"',
#   '"In His Famous STAIR DANCE"',
#   '"In His Famous Fan Dance and the Continental"'],
#  'Del Le Roy': ['"Southern Aristocrat of the Dance"',
#   'identified themselves as Del Le Roy in court?',
#   'unclear who was in drag or not here',
#   '"Del LeRoy joins Bell in doing a modernized version of Tschaikowsky\'s \'First Piano Concerto\'—much better known now as the \'Piano Concerto in B-Flat Minor.\'"',
#   '"A Ziegfeld Follies favorite—"You Stepped Out of a Dream"—in the sultry voice of Del LeRoy, is one of the outstanding numbers done by this star of three seasons in Karyl Norman\'s male revue at the Club Frontenac . . . LeRoy also sing \'Memory of a Rose.\'"',
#   '"His Final Week"'],
#  'Norman Lewis': ['"acrobatic dancer, who has just finished an extended engagement with Sally Rand"'],
#  'La Belle Rose —': ["called Scotch female impersonator -- is this the person who Rae Bourbon used to be in a vaudeville team with under the name Scotch and Bourbon? (see Literati: Femme Impersonator's 'Hookers' Variety 107, no. 11, August 23, 1932, 40.)",
#   'Scotch performer alleged to be back in November'],
#  'Lena Rivers': ['"pansy comic" - does a fan dance in long underwear, together with Art West?'],
#  'Art West': ['"pansy comic" - does a fan dance in long underwear, together with Lena Rivers?'],
#  'Gene Pearson': ['master of ceremonies until his untimely death at 34'],
#  'Tony? Eddie? —': ['A lot of their work is in drag, and they create comedy moods with their costuming. Eddie Gruber "worked from a wheelchair, because of a physical disability . . ."'],
#  'Robert G. Brennan': ['Name inferred from Times Union, July 23, 1935, 15'],
#  'Billie Brannon': ['"Gorgeous Singing Type"',
#   '"Characterizations"',
#   '"Winchell\'s Choice of Impersonators"',
#   '"Lovely Impersonator"'],
#  'Gene Abbott': ['"Last, but not least, Gene Abbott, a newcomer with the group makes his debut with the group this weekend. He hails from the Oklahoma territory, being of CHerokee blood . . . and American . . . he has a real \'warhoop\' of his own. A master entertainer and a singer of note."'],
#  'Nicki Gallucci': ['"Nicholas Galouchie is a recent addition to the show. Since his debut at the Club Richman he has received the praise of both the diversion seekers and the local press."',
#   '"Golden Voice Soprano"',
#   '"Later Gallucci states that his gowns are those worn by Constance Bennett in her latest picture"',
#   'Featured with photo',
#   '"Catch Nicki Gallucci\'s turn at the one and only Finocchio\'s. In fact, catch the whole revue. Then you\'ll have some idea of why this spot draws \'em in week and week, come rain or shine, neon or blackout"',
#   '"ADDED ATTRACTION . . . OUR MALE LILY PONS"'],
#  'Tex Hendricks': ['Likely him anyway... Referred to as Francis Hendricks in the article. "Another addition to the Club Richman show [Jack Mason\'s Playboy Revue] is Francis Hendricks who is acting as master of ceremonies for the Playboy unit."',
#   'one of them is a "femme impersonator, in blackface"',
#   'Appeared as "sepia dame"',
#   'Dead at age 51 (?).'],
#  'Adrian Ames': ['"The Fabulous Male Impersonator . . . Hollywood\'s Glamorous Delineator of Song and Fashion"',
#   "The Birmingham News, October 4, 1925, 6 corroborates Lionel Mike Ames's name as Adrian Ames",
#   'Variety, Sept. 10, 1930, 17, and \rSept. 24, 1930, 68 corroborates that Mike Ames = Adrian Ames',
#   'Variety, Sept. 10, 1930, 17, and \nSept. 24, 1930, 68 corroborates that Mike Ames = Adrian Ames'],
#  'Mickey Arnold': ['(I accidentally removed the comment here...)'],
#  'Chris Bailey': ['"Sophisticated Chatter Box"'],
#  'Babe Baker': ['"25 of the World\'s Foremost Female Impersonators"; "2nd big week"'],
#  'Jean Barrios': ['"Dean of Female Impersonators"; "Sings in Three Voices"'],
#  'June Beal': ['"Songs, Dances"'],
#  'Bobbie Bell': ['"Character Dancer"',
#   '"Bell does an interpretation of a Siamese dance of the era before it became Thai and began militarizing."'],
#  'Jack Mason': ['emsee'],
#  '— Osborne': ['As part of DeMarco & Osborne'],
#  'Gene Renee': ['"celebrated European mimic" - recently at Kit Kat Club in London',
#   '"mimic"'],
#  'Bert Sherry': ['At the venue for the past seven months',
#   'For legal name, see See 1938-07-30 The Billboard, Jul 30, 1938, 67 [Bert Peaches Buckingham, Baltimore]'],
#  'Francis Blair': ['"bouncing ball routine"'],
#  'Pepe Blaire': ['"Male Joan Crawford"'],
#  'Bobbie Brennan': ['"master of ceremonies"',
#   'MC',
#   '"guides the show suavely"',
#   '"master of the ceremonies"'],
#  'Bothwell Browne': ['"Dancing Diana"'],
#  'Nada Bryant': ['in the chorus. uncertain whether she was in drag. Here, it\'s written that she "never cease to amaze the customers"'],
#  'Douglas Byng': ['"At any rate, he\'ll attract trade, especially from the pencilled eyebrow set."'],
#  'Peppy Carman': ['MC'],
#  'Gerry Carroll': ['Featured in a photo!'],
#  'Lanny Brice': ['"no longer associated with Lyle Page\'s Playboys"',
#   '"former impersonator, . . . now producing the shows at Gamble Inn"',
#   'comedian',
#   '"finished a summer\'s run at Benton Harbor . . . now at the Moonlight Gardens, Springfield, Ill."'],
#  'Dixie Jean': ['"one of Chicago\'s leading female impersonators"'],
#  'Alden Garrison': ['Here described as "dressed in a white fur-trimmed creation with a shoulder cape attached. His girlish-bobbed hair was slicked back, making his female impersonation almost perfect."',
#   '"well known in night club circles in the east for the part he played as a female impersonator . . . buried last week"',
#   '"The glamorous boy, who for the past twelve years has been an entertainer in both colored and white clubs and hotels, and has won many cups, prizes and trophies as the best dressed female impersonator in the pansy balls of Baltimore, Atlantic City, and New York, died forgotten and practically alone."'],
#  'Kitty May': ['Here described as singing "Just a Shanty in Old Shanty Town," and then "pulled up his dress waist high and revealing the daintiest of women\'s unmentionables."'],
#  'Ralph Gilbert': ['"Ballad Singer"',
#   '"Acrobatic Dancer"',
#   '"toe dancer"',
#   '"Twisted Rhythm"',
#   'credited as "Sensational Acrobatic Dancer"'],
#  'Jacquette La Marr': ['Crooner',
#   '"that explosive bit of personality"',
#   'Personality Singer',
#   '"Singer of Popular Songs"',
#   'MC'],
#  'Pep Murray': ['"Impersonating Mae Murray"',
#   '"Sensational Redhead"',
#   '"That Scintillating Redhead"'],
#  'Lee Mason': ['a femme-female drag queen - a sign of the vibrant drag culture at this time in the country...'],
#  'Albert Henry Cook': ['Stole jewels, pawned them for $1,200, "and used the money to travel, finally hooking up with a carnival in which, with the aid of some artificial attachments, he starred as a can-can dancer. In Chicago, police said, he attended a fancy dress ball in an evening gown, first taking the precaution to hire a private detective for $30 plus expenses to protect him."'],
#  'Jack Craig': ['unclear who was in drag or not here'],
#  'LaVerne Cummings': ['arrested "after being detected as an entry in a \'Miss National Boat Race of 1952\' contest at the film house. He dressed in a woman\'s bathing suit and wore a hair ribbon, makeup, and high-heeled shoes which lace up the leg."',
#   '"Early in his career . . . starring in the Jewel Box Revue in Miami, Florida"'],
#  'Mona La Fountaine': ['"has the \'freak soprano\' voice"'],
#  'Connie Walsh': ['"6 ft. 3 of Mirth"',
#   '"6 ft. 3 of Mirth in \'I\'d Rather Be Spanish Than Mannish"',
#   '"You\'ll Scream!"',
#   '"Six Foot Three\' of Mirth"'],
#  'Gorda Davies': ['"What a Singer"'],
#  'Frankie Davis': ['"The Male Dagmar—Smart Singer of Songs"'],
#  'Dennis Griffin': ['MC'],
#  'Dave Davis': ['"The Male \'Gypsy Rose Lee\'"'],
#  'Wesley Davis': ['"Singer–Strip"'],
#  'George Kelly': ['The Male Texas Guinan',
#   'MC',
#   'Part of "Jean & George" act, described as "something very gay."',
#   'Part of "Jean & George" act.'],
#  'Donnie Dawn': ['"Exotic Dancer"'],
#  'Bunny Daye': ['"The Body in a Million"'],
#  'Clinton De Forrest': ['Dead'],
#  'Frances Dee': ['"that classy female impersonator . . . formerly a feature with Valda Grey\'s Cabin Inn revue."'],
#  'Robert Dell': ["Unclear if it's really Robert Dell. Wounded in leg following a shot to the stomach at a stickup"],
#  'Jules Diamond': ['"Broadway Musical Star — The Male Gypsy Rose Lee"'],
#  'Frank Doran': ['"The Belle of the Barbary Coast"'],
#  'Bobbie La Marr': ['identified themselves as Bobbie La Mar in court',
#   'Third prize winner at the ball'],
#  'Willie Duices': ['Died in November'],
#  'Eugene Ebol': ['serious condition following a shot to the stomach at a stickup'],
#  'Harvey Lee': ['"The Most Beautiful Boy in the World"',
#   '"Direct from the Flamingo Club in Hollywood"; "Alluring and Beautiful"',
#   '"The Only Female Impersonator who has Appeared in Earl Carroll Vanities"'],
#  'Roni Warren': ['MC', '"The Male Mae West"', '"Something Different"'],
#  'Bobby Ferguson': ['"dancer"'],
#  'Tony Collins': ['"\'Fairy Dance\' promoter\' getting ready for his last \'Drag Ball\' . . . will he have a mob at Elk\'s hall next week?"'],
#  '— Garrison': ['From Washington DC'],
#  'Billy Hayes': ['"Prima Donna"',
#   '"soprano"',
#   'prima donna',
#   '"male soprano"',
#   '"male soprano, described as the boy with a million dollar voice"'],
#  'Gita Gilmore': ['"doing a Shirley Temple number"',
#   '"Male Mae West"',
#   '"comic"'],
#  'Eddie Crawford': ['"Kitty of the 27th Division"'],
#  'E. Russell': ['Legal name, see Drag 3, no. 12, p. 22'],
#  'Clarence Weems': ['"[show is] emceed by Mr. Clarence Weems (who is making his seventh year stand at Joe\'s [sic] . . ."'],
#  'Petite Swanson': ['"sings the blues you like to hear"'],
#  'Ivey ("Caldonia") Anderson': ['"does a dance you like to see"'],
#  'Dixie Lee': ['"sings the songs that make you swoon"', '"Singing M. C."'],
#  '— Jarahal': ['"exotic sex Interpeter [sic] Dancers" Unsure whether this is Jarahal but at least it seems like it could be...?',
#   'Could name be Jarvis Hall?',
#   'No longer in drag, likely. Here called "Prince Jara Hall," a "specialist in two vocal registers".'],
#  '— Ginger': ['"exotic sex Interpeter [sic] Dancers"'],
#  'Herslean Roberts': ['1st prize winner'],
#  '— Skelly': ['2nd prize winner'],
#  '— Shirline': ['3rd prize winner'],
#  'Rodney Griffin': ['MC'],
#  'Prince Hanalei': ['"World\'s Only Male Exotic Dancer" + "Cast of ten Boys will be GIrls"'],
#  'Leon LaVerde': ['conflict over higher billing than stripper'],
#  'Chick Chandler': ['taking off on a burlesque stripper'],
#  'Kenneth Hawkins': ['Member of "Krazy Katz"'],
#  'Billy ("Senorita") Herrera': ['"South American Bombshell"',
#   '"rated the best imitator of the Gypsy of any sex. Overcoming language difficulties, Herraro satirizes her singing style and mimics perfectly her diffident strip technique. His makeup as a woman is deceiving even in the intimate confines of the night club. He headlines the Gay Boy Revue, now in its 10th week. The Lyndall Dancers, genuine feminine precision dancers will be added to the show beginning Monday, Labor Day. Other acts include..."; see also https://handeaux.tumblr.com/post/631310750800117760/the-true-story-of-ucs-male-homecoming-queen?is_related_post=1',
#   'Senorita Herraro: Brazilian Gypsy Rose Lee',
#   '"the finale stars the Spanish-English singing star of the club, Billy Herrero. The Li-Kar costume worn by Herrero during the elaborate spectacle is typical of the era which saw the origination of the hat dance, and, according to the Hollywood designer, it is completely authentic."',
#   '"The South American Bombshell"',
#   'Featured with image',
#   '"The new \'Gay Boy Revue\' [edition] will headline Billie Herraro, whoo calls himself the Brazilian Gypsy Rose Lee."',
#   '"billed . . . as the \'Brazilian Gypsy Rose Lee,\' is rated the best imitator of the Gypsy of any sex. Overcoming language difficulties, Herraro satirizes her singing style and mimics perfectly her diffident strip technique. His makeup as a woman is deceiving even in the intimate confines of the night club. He headlines the Gay Boy Revue now in its 10th week."',
#   'Featured with photo',
#   '"sensational mimic of the female impersonator school"',
#   '"billed as the \'Brazilian Gypsy Rose Lee.\'"',
#   '"Cuban Bombshell"',
#   'headlining as "Brazilian Gypsy Rose Lee"',
#   '"master of ceremony . . . introduces the star of the show, Billy Herrero, the South American bombshell, who surprises patrons with his act of Latin songs and dances."',
#   '"Billy Herrero heads the show at the Top Hat Club with female impersonations and Latin songs and dances that reveal wide range." Featured with picture',
#   "Review of the performance; lots of descriptions of Herrera's acts here",
#   '"OPENING TONITE BILLY HERRERO The Brazilian Sensation"',
#   '"Sensational Impersonations Gipsy Rose Lee and Carmen Miranda"',
#   '"Billy Herrero who is making the town talk with his Gypsy Rose Lee number at the Five O\'Clock, will be held over at that club."',
#   '"Sensational Impersonations"',
#   '"Brazilian Sensation"',
#   '"being held over another week"',
#   '"TONITE... SURPRISE ??????? with BILLY HERRERA imp ????"',
#   '"Your best friend won\'t tell you ALL about BILLY HERRERA — Impressionist" "The MOST UNUSUAL ACT TO VISIT THE PALM BEACHES"',
#   '"SMALL WONDER that Billy inspired Life and Look magazine features!" "You\'d swear you\'re applauding Gypsy Rose Lee, Hedy LaMarr, Carmen Miranda. And you\'ll see a finale to startle you out of your seat (mum! if you\'ve seen the show; don\'t spoil the fun for others.)"',
#   '"See the most exciting personality you ever saw! BILLY HERRERO — Vivid Latin impressions. Spitfire of Carman Miranda, piquancy of Hedy laMarr, bombshell of emotion. The rumba, samba, conga like you\'ve never seen before. And the finale, one that marks an artist—well, to be astonished you must see for yourself!"',
#   'Part of the floor show.',
#   '"Floor Show With An All Star" "BILLY HERRERO—Your chance to see a great artist. Feminine Impersonator without present day equal. Carbon copy of Gypsy Rose Lee, Hedy Lamarr, Carmen Miranda. Kick yourself if you miss it."',
#   '"Featured in the stage presentation [in this vaudeville presentation] will be Billy Herrero, who impersonates such female personalities as Gypsy Rose Lee, Carmen Miranda and others."',
#   '"4 GREAT Vaudeville Acts" "35 LOVELY GIRLS ON PARADE" "Billy Herrero—Female Impersonator"',
#   '"The main attraction, Billy Herrero\'s impersonations of women, fails to register and Billy leaves the stage with the audience clinging to the impression that he really is a \'she.\' His act is slow, and while he is dressed in much the manner Carmen Miranda would garb herself, his voice doesn\'t sound at all like the popular move actress."',
#   '""BILLY HERRERA—The \'Gypsy Rose Lee\' of Brazil"',
#   'only "HERRERO—The Brazilian Gypsy Rose Lee"',
#   'only "HERRERO—The Brazilian Gypsy Rose Lee" Adding "DON\'t MISS THIS SENSATIONAL SURPRISE ACT—?—You\'ve Seen Gypsy—Now See \'Herrero\'"',
#   '"DON\'T MISS Herrero—\'The Brazilian Gypsy Rose Lee\'—ENTERTAINING—SENSATIONAL—SURPRISING—We think this act is tops—and you will too. Don\'t say we didn\'t tell you."',
#   '"Back Again The Popular Star BILLY HERRERA as Gypsy Rose Lee, Carmen Miranda, Dorothy Lamour"',
#   '"HERRERO—\'The Brazilian Gypsy Rose Lee\' offers this week Pulsating Latin Rhythms a la CARMEN MIRANDA"',
#   '"one of the most unique acts to play this section this season, Billie Hererro, the \'Brazilian Gypsy Rose Lee.\'"',
#   '"Billed as the \'Brazilian Gypsy Rose Lee,\' Billie Herrara is the current attraction at the Club Granada."',
#   '"Presenting the Brazilian \'Gypsy Rose Lee\' BILLY HERRERA Famed Latin Impression Star"',
#   '"He\'s well known for impressions of stage, screen and radio notables."',
#   'Billed as "Senorita Herrero"',
#   '"opens . . . tomorrow night"',
#   '"EXTRA ADDED ATTRACTION"',
#   '"Brazillian Gypsy Rose Lee, Senorita Herrero, has been signed to headline a new show opening Tuesday at Club 22. The senorita\'s unique act will top an all-Latin program . . ."',
#   'Billed only as "BRAZILIAN GYPSY ROSE LEE"',
#   'Billed only as "Senorita HERRERA—Brazilian Gypsy Rose Lee"',
#   'Billed only as "Senorita HERRERA—The Brazilian Gypsy Rose Lee" "BREEZY—TEEZY—SENSATIONAL" "BREATHTAKING .... DARING"',
#   '"Opening Saturday For One Week Only — That Continental Sensation — BILLY HERRERO" "The greatest of all FEMALE IMPERSONATORS. You\'ll marvel at him. Your one and only chance to see this clever artist at the REDWOOD CLUB."'],
#  'Vernon Hoff': ['third week; "Dayton\'s favorite boy strip tease dancer."'],
#  'Beatrice Howle': ['she\'s a "fem impressionist" i.e. a female-female drag queen'],
#  'Nina Rae': ['"hostess, keeps everybody happy"'],
#  'Olin Landick': ['femme imp monologist',
#   '"would be better if he cut out the salacious material"'],
#  'Bobby Anderson': ['"Understudy to the late Jean Malin"',
#   '"Constant—Continuous—Convulsive Entertainment! Tantalizing—\'Toe-Tickling Dance Melodies"'],
#  'Billie Dale': ['"Boy With Million Dollar Legs"'],
#  'Terry La Monte': ['MC',
#   '"male Jean Harlow"',
#   '"who closely resembles the late Jean Harlow"'],
#  'Jean Jennings': ['Part of "Jean & George" act, described as "something very gay."',
#   'Impersonations',
#   'Part of "Jean & George" act.'],
#  'Jackie Adams': ['International Nightingale'],
#  'Jean La Rae': ['"the male Texas Guinan"'],
#  'Don Rand': ['"Aristocrat of Dance"',
#   '"Vaudeville\'s Capital Comedian"',
#   'credited as "Comedy Sensation"',
#   'unclear who was in drag or not here',
#   'Same as Don Rand?',
#   '"Sensational Toe Dancer"'],
#  'Garry Teasdale': ['"Singer of Modern Melodies"'],
#  'Billy Kamp': ['"of New York, one of the country\'s best skilled female impersonators, is to join the \'Gay Boy Revue\' Friday night . . ."',
#   '"singer of sophisticated songs"'],
#  'Bobby Stevens': ['MC'],
#  'Billie Kemp': ['"singer of sophisticated songs"'],
#  'Klare Kenney': ['advertisement: "I know that life begins at forty but still Glamorously Gay"'],
#  'Jack King': ['"Comedian"'],
#  '— Knox': ['both female impersonators'],
#  'Viola Layne': ['she\'s a "fem impressionist" i.e. a female-female drag queen'],
#  'Johnny Mangrum': ['credited as "M. C. and Prima Donna"',
#   '"Singer of Sophisticated Songs"',
#   'unclear who was in drag or not here'],
#  'Eddie Morton': ['credited as "Torch Singer"'],
#  'Danny Lee': ['"Danny Lee, a Louisiana boy, who was graduated from Loyola University in New Orleans, and is a dancer of note, having danced in bigtime at the Ha-Ha! Club in Florida, has an enviable record as an entertainer of note. He is teamed with this group and is one of the stellar performers."'],
#  'Eddie Lee': ['MC'],
#  'Bobby Brennan': ['"Sophisticated Songster"', '"Sophisticated Singer"'],
#  'Jean Farrelly': ['"Elissa Landi of Nite Life"'],
#  'Thelma Lee': ['headliner'],
#  'Bobby Norman': ['"The Boy With the Million-Dollar Legs" — "in the Continental"',
#   '"See Bobby Norman\'s Carioca"',
#   'Carioca Dancer',
#   '"That Talented Boy with the Million Dollar Legs In the Famous Continental and Carioca"'],
#  "Billy O'Brien": ['"Inimitable Comic"'],
#  'Alberta Vaughn': ['Exotic Personality',
#   '"Exotic Personality Songs and Taps"',
#   '"Exotic Personality"',
#   '"well known for her screen and stage work"',
#   '"former screen actress"'],
#  'Bobby Verrill': ['"The Male [Harriet] Hoctor"'],
#  'Madam Dubarry': ['"creating a sensation with his song-and-dance routine." "new-comer here, is breaking into the clubs via the guest route."'],
#  '— Mack': ['both female impersonators'],
#  'Tommy Mann': ['whoever is tallest, is referred to in the review as having done a female impersonation. I am guessing it is Tommy Mann based on "Los Angeles: Orpheum," Variety 92, no. 7, August 29, 1928, 62.',
#   "he's the one behind the College Flirt sketch.. one of the few that we have documented!"],
#  'Andy Cliff': ['"impersonating Sally Rand"',
#   'Featured with photo!',
#   '"impersonation of Sally Rand"'],
#  'Billie Davis': ['"company is headed by Billie Davis"'],
#  'Arica Wild': ['"in a unique interpretation of the carioca"',
#   '"in a unique interpretation of the Carioca"'],
#  'Harild Ishem': ['operator (not really a performer?)'],
#  'Mitzi Mantis': ['"He had been the torch singer of the resort [Rhythm Club], wearing a dazzling gown that revealed his powdered shoulders, and a wig of dainty curls. A chorus of other female impersonators had minced around him during his numbers. But Mitzy had far outshone the others." — "Mitzy, also known as Agnes, had come of respectable parents and had received a fairly good education. When jobs became hard to find, during the depression, he had drifted into Pittsburgh night life. At the Rhythm Club, the town\'s most notorious resort, he had found his level as a singing female impersonator."',
#   'This article describes him as George (Mitzi) Mantis, 19 years old...?'],
#  'Micky Marlow': ['fan dance'],
#  'Kerri Marlowe': ['"dancer"'],
#  'Niles Marsh': ['unclear who was in drag or not here'],
#  'Jackie Maye': ['"now singing \'straight\'"',
#   '"Only Female Impersonator to play in MOTION PICTURES . . . Heading a new ALL-STAR cast of the leading Female Impersonators in the business."',
#   'Star billing'],
#  'Gay Byerd': ['"Acrobatics Supreme"'],
#  'Lee Carroll': ['"Delineator of Song"'],
#  'Ina Gaskill': ['"America\'s Most Beautiful Chorus Boy"'],
#  'Paul Gilrey': ['"Singer of Sweet Songs"'],
#  'Davy Lee': ['"The Male Ann Pennington"'],
#  '— Page? Hudeck?': ['"Sensational Dance Team"'],
#  'Clare St. Clair': ['"The Personality Boy"'],
#  'George Mason': ['Described as "a young man who does a delightful turn of mimicking in draggy fashion to offstage recordings. His clever mouth routine is especially effective while raking Yma Sumac over the glissandos."'],
#  'The Mystery Dancer —': ['"daring and diverting dances"'],
#  'Jackie Lee': ['"Sophisticated Song Styles"'],
#  'Soni Sinclair': ['"brilliant wit and comedy"'],
#  'Sandra —': ['Washington DC-based'],
#  'Jay Albert': ['Second prize winner at the ball'],
#  'Phil Black': ['Fourth prize winner at the ball'],
#  'Gus Dreyfus': ['Washington DC-based'],
#  'Eddie Green': ['Washington DC-based'],
#  'Joe Johnson': ['Washington DC-based', 'Second prize winner'],
#  'Jean LaMarr': ['First prize winner at the ball'],
#  'Geane Ray': ['First prize winner. "wore no costume at all. He was attired in the simplest of street dresses, orchid in color. He wore a corsage of gardenias, plain black shoes, flesh colored silk hose, and no hat. His naturally grown wavy titian hair, cut in page boy length, was \'beautiful,\' in the words of his admirers." "Ray did not march sedately across the floor while the winner was being picked. He executed a half dance back and forth, holding his arms gracefully aloft. To ordinary eyes, here was a slim young girl in an orchid dress, 5 feet 4 inches tall, weight about 108, waist about 24 and hips 28."'],
#  'Steel Smith': ['Washington DC-based'],
#  'Michal Michalesko': ['"the only female impersonator on the Yiddish stage"'],
#  'Toni Midnight': ['Male Hedy Lamarr'],
#  'Toni Midnite': ['"World\'s Most Beautifully Gowned Boy"'],
#  'Stuart P. Murphy': ['"What a Man"'],
#  'Bobby Grant': ['sepia femme impersonator'],
#  'Dan Carson': ['manager'],
#  'Carl Nixon': ['blackface female impersonation'],
#  'Karyl Norman': ['likely not performing but managing',
#   'Norman is not doing any dress numbers; he is doing vocals in a rich baritone',
#   'has evidently quit the vaudeville stage for the present . . . signd with Abe Carlos, husband of Gilda Gray to do a number of feature pictures.',
#   '3 year contract',
#   'stopped his act halfway because he was not receiving enough applause - he was later rebuked for his action and the head of the Keith Circuit wrote "informing him in part he would never again be afforded an opportunity to criticize any audience in any of the houses on the Keith Circuit."',
#   '5 year contract in total?',
#   '"Vet impersonator recuping from serious illness in Ft. Lauderdale" = Jewel Box had a benefit performance',
#   '". . . about to start on a tour of the Fox Houses around New York. For many seasons Keith-Albee and the Orpheum circuits have utilized Norman as a headliner."',
#   '"New Yorkers just learning of the death in California of Caryl [sic] Norman, onetime headliner at the Palace as a female impersonators. He was completely broke."',
#   'originally scheduled to appear but was "pulled out yesterday"',
#   '"reverts to a bygone vaudeville program . . . Norman appears to depreciate the old type turn to the extent that he is not a \'female impersonator,\' but rather a \'character delineator.\'"'],
#  'Al Lucas': ['"Night Club Nightingale"'],
#  'Bobbie Marlowe': ['"The Blonde Venus"'],
#  'Frank Perry': ['"as Fanny Brice"'],
#  'Ted Shaw': ['"Incomparable M. C."'],
#  'Jabby Caruso': ['Name inferred from Times Union, July 23, 1935, 15'],
#  'Theodore Coppi': ['Name inferred from Times Union, July 23, 1935, 15'],
#  'David J. Doyle': ['Name inferred from Times Union, July 23, 1935, 15'],
#  'Max Lengel': ['Name inferred from Times Union, July 23, 1935, 15'],
#  'Thomas Martin': ['Name inferred from Times Union, July 23, 1935, 15'],
#  'John D. May': ['Name inferred from Times Union, July 23, 1935, 15'],
#  'Jean Arnold': ['"Male Betty Boop"'],
#  'Jackie Dayton': ['"Male Gilda Gray"'],
#  'Frances Lee': ['Male Jean Harlow and M. C.'],
#  'Wilkie Mason': ['"Prima Donna"'],
#  'Cleo Renee': ['"Prima Donna"', '"Male Prima Donna"'],
#  'Verida Pearson': ['"veteran female impersonator will also perform as well as several other promising young artists in musical rendition."'],
#  'Billy Richards': ['"doffs the clothes and dons the feathery fans this week in the floor revue"',
#   '"Billy Richards the gay guy, from Hollywood, a graduate of Northwestern University of Chicago, who designs and makes his own gowns used in the entertainment. He played at Bal Tavern, San Francisco, as a singer for 27 weeks before joining the troup to fulfil [sic] the contract here."'],
#  '— Doran? West? Doran?': ['"The three \'maidens\' first come dashing out done up as beauties along the type of Floradora girls. Then two of them do a travesty upon the Margie of Savoy and Brennan. Then a corking red-headed impression of a prima donna going nuts. Then the smash hit of the act, their own impression of the Duncan Sisters. Their get-up, meaning their dresses, are screams, reminding one of an ocean wave. Here is artistry of burlesque done in rare style. Maybe you do not care for this type of broad female impersonations, but these men have real artistry back of all their non-sense. They handed me a terrible comedy wallop. They close their act with a burlesque, the Russian Bat theater. Good costumes and a fine idea is worked out by the three. Here is a female impersonation act that is different, and to me it is a wow. If you laugh along those lines you will have a grand time."'],
#  'Jackie Phillips': ['"The riotous redhead"'],
#  'Carlo Levins': ['"Control Dancer"'],
#  'Francois Densmore': ["Unsure whether it's Densmore, but likely"],
#  'Frank Quinn': ['Master of Ceremonies'],
#  'Francis Renault': ['"the banana-throwing, rose-giving female impersonator"',
#   '"Renault, it transpires, is a \'former Ziegfeld Follies star, who has been named as correspondent in three divorce actions, wooed by the emperor, assaulted by enraged wives and has been dubbed \'the mystery of science and sex.\' His tricks run from an imitation of Mae West to Mary Pickford."',
#   'dropped out after two performances'],
#  'Daisy Navarro': ['"stopping the show with his version of the famous fan dance. . . . The gal is wow-ing the bunch—trousers, cocktail jacket, \'n\' everything."'],
#  'Sylvan Repetti': ['pending Pleasure Man trial',
#   'credited as a "snake dancer"'],
#  'James Riley': ['partner of Johnny Hudgins; dead; survived by wife and three kids',
#   'Guessing that this is James Riley based on other sources that mention him in 1920, 1921, 1927, etc.'],
#  'Jo-Jo —': ['World-famous Clown'],
#  'Babe Allen': ['"Hot Cha" boy from Chicago'],
#  'Jene Cortez': ['"The Rhythm Whirlwind In The Lavish and Distinctive Spectacle"'],
#  'Marty Deem': ['"Constant—Continuous—Convulsive Entertainment! Tantalizing—\'Toe-Tickling Dance Melodies"'],
#  'Francis Russell': ['"Francis Russel of Philadelphia, Pa., is another of the entertainers, who appeared in Olson & Johnson\'s \'Hellzapoppin\',\' the Wonder Bar Club and in the \'Mack and Wig Shows.\' He is a graduate of the University of Pennsylvania."'],
#  'Jack Hughes': ['"Constant—Continuous—Convulsive Entertainment! Tantalizing—\'Toe-Tickling Dance Melodies"'],
#  'Stanley Jabin': ['Operator but likely not performer'],
#  'Gabby Lee': ['"Constant—Continuous—Convulsive Entertainment! Tantalizing—\'Toe-Tickling Dance Melodies"'],
#  'Lyle Mack': ['"America\'s Most Beautiful Boy"'],
#  'Walter McDonald': ['"Constant—Continuous—Convulsive Entertainment! Tantalizing—\'Toe-Tickling Dance Melodies"',
#   'Impressions of Helen Morgan'],
#  'Ray Saunders': ['"The Toast of San Francisco"'],
#  'Floyd Savage': ['"maintained he was on his way to a Halloween party" when he got arrested, five days in jail.'],
#  "Sonny O'Shea": ['"Constant—Continuous—Convulsive Entertainment! Tantalizing—\'Toe-Tickling Dance Melodies"'],
#  'Julia Stevens': ['"Exotic Dancer"'],
#  'Au Sing': ['"Female impersonators, somewhat rare in the occidental theater, still are the vogue in the oriental theater, according to Au Sing, now headlining at the \'Gay Boy Revue\' . . . Au, himself, was trained in the stylized traditions of the Chinese stage. The dances he presents at the New Look Club are, he says, authentic reproductions of Chinese choreography. The Sword Dance, which Au features, is one of the more popular Chinese dances."',
#   '"exotic"',
#   '"America\'s only Chinese female impersonator, will present his Saber dance at the opening tomorrow on the new edition of the \'Gay Boy Revue\' . . . He was taught the dance by a pupil of Mui Lan Fong, venerated Chinese dancer. Mui Lan, now 75, lives in retirement in Peking where he achieved fame as a female impersonators in the traditional Chinese theater."'],
#  'Margaret Cook': ['Margaret Cook and Ted Cook together perhaps?'],
#  'Gordon Stafford': ['"Oriental Dancer"'],
#  'Al Sterling': ['MC; "America\'s Newest Singing Sensation"'],
#  'Stacy Stevens': ['"striptease sensation"'],
#  'Francis Stillman': ['"singer"'],
#  'Bobby Sullivan': ['MC'],
#  'Georgie Kaye': ['MC'],
#  'Sonny Teal': ['"Darling of the Dance"'],
#  'Verne Valdez': ['"Comedy Singer and Dancer"', 'Eighth month at the venue'],
#  'Jerry Vaughn': ['"Acrobatic Dancer"'],
#  'Billy Irwin': ['"male Libby Holman"'],
#  'Melba —': ['Becomes a father'],
#  'Joanne Crawford': ['Arrested.'],
#  '— Williams': ['"Mr. Williams as a female impersonator is \'peaches.\' He not only looks the part, but he is graceful and makes quite a nice looking girl. Of course the laugh is a little heavy, but what do we care when we know it is not a real live woman with a laugh like that . . ."'],
#  'Bert Errol': ['In 1921, Bert Erroll shocked Chicago: "Before making a change he bared one side of his body almost to the waist to show he really was a man. Spoiled his hit."'],
#  'Bobbie Grant': ['"well known female impersonator, best known as the \'Creole Fashion Plate.\'"'],
#  'Juanita B. Talmadge': ['"returned from an extensive tour of the British Guiana, West Indian Islands, and other South American ports where he won many laurels. Owing to his charming personality and perfect make-up he is regarded as America\'s premier female impersonator."'],
#  'Charles Wilhelm': ['"His name may be recalled by vaudeville patrons of a score and more years ago. The 76-year-old man once trod the boards as a female impersonator and his name appeared in lights outside the theatres. His body, clad in one of the costumes he wore at the height of his career, was found this morning lying face downward on his bed. Beneath his nostrils was a wad of cotton soaked with chloroform." "Wilhelm was dressed in silken underwear, silk stockings, white, hiehg-heeled pumps and on his head was a blond wig. It was the one costume he cherished." "police opined it was not poverty, but loneliness that caused him to put on his costume and play his last role in life."']}
