# %%
from datetime import timedelta, datetime
import pandas as pd
import re

# %%
day_diff = 7
date = datetime(2020,1,1)

range_start = date + timedelta(days=-day_diff)
range_end = date + timedelta(days=day_diff)

date_range = [range_start + timedelta(days=x) for x in range((range_end-range_start).days + 1)]

date_range
# Out:
# [datetime.datetime(2019, 12, 25, 0, 0),
#  datetime.datetime(2019, 12, 26, 0, 0),
#  datetime.datetime(2019, 12, 27, 0, 0),
#  datetime.datetime(2019, 12, 28, 0, 0),
#  datetime.datetime(2019, 12, 29, 0, 0),
#  datetime.datetime(2019, 12, 30, 0, 0),
#  datetime.datetime(2019, 12, 31, 0, 0),
#  datetime.datetime(2020, 1, 1, 0, 0),
#  datetime.datetime(2020, 1, 2, 0, 0),
#  datetime.datetime(2020, 1, 3, 0, 0),
#  datetime.datetime(2020, 1, 4, 0, 0),
#  datetime.datetime(2020, 1, 5, 0, 0),
#  datetime.datetime(2020, 1, 6, 0, 0),
#  datetime.datetime(2020, 1, 7, 0, 0),
#  datetime.datetime(2020, 1, 8, 0, 0)]

# %%
df = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vT0E0Y7txIa2pfBuusA1cd8X5OVhQ_D0qZC8D40KhTU3xB7McsPR2kuB7GH6ncmNT3nfjEYGbscOPp0/pub?gid=0&single=true&output=csv')

# %%
for ix, row in ((x, y) for x, y in df.iterrows() if re.search('\d{4}\-\d{2}\-\d{2}', str(row['Date']))):
    row['Date']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-13427a585343> in <module>
# ----> 1 for ix, row in ((x, y) for x, y in df.iterrows() if re.search('\d{4}\-\d{2}\-\d{2}', str(row['Date']))):
#       2     row['Date']
#
# <ipython-input-52-13427a585343> in <genexpr>(.0)
# ----> 1 for ix, row in ((x, y) for x, y in df.iterrows() if re.search('\d{4}\-\d{2}\-\d{2}', str(row['Date']))):
#       2     row['Date']
#
# TypeError: tuple indices must be integers or slices, not str

# %%
df = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vT0E0Y7txIa2pfBuusA1cd8X5OVhQ_D0qZC8D40KhTU3xB7McsPR2kuB7GH6ncmNT3nfjEYGbscOPp0/pub?gid=0&single=true&output=csv')
df = df.fillna('')
# Out:
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...
# already deleted...

# %%
df2 = df.copy()

for ix, row in df.iterrows():
    if not row['Exclude from visualization']:
        df2 = df2.drop(ix)
        
    if not re.search('\d{4}\-\d{2}\-\d{2}', str(row['Date'])):
        try:
            df2 = df2.drop(ix)
        except KeyError:
            print('already deleted...')
# Out:
#             Date Category Performer Normalized performer Performer first-name  \
# 587   1930-10-15                             Gypsy Byrne                Gypsy
# 588   1930-10-15                           Billie Gerber               Billie
# 627   1931-01-24                              Jean Malin                 Jean
# 5703  1942-04-14                                       —                    —
# 5704  1942-04-17                                       —                    —
# 5706  1942-04-28                                       —                    —
# 5723  1942-06-13                                       —                    —
# 5736  1942-07-07                                       —                    —
# 5737  1942-07-15                              Ted Curtis                  Ted
# 5788  1942-08-29                                       —                    —
# 6213  1947-02-05                               Tim Moore                  Tim
# 7266  1952-03-29                                       —                    —
# 7796  1965-10-06                           Ross Hamilton                 Ross
# 7835  1968-04-13                             T. C. Jones                T. C.
# 7879  1976-10-27                              Jim Bailey                  Jim
# 7881  1978-01-31                                       —                    —
# 7882  1978-05-17                          Charles Pierce              Charles
# 7883  1979-08-18                                       —                    —
# 7902  1988-03-02                              Jim Bailey                  Jim
#
#      Performer last-name                                Venue  \
# 587                Byrne                                    —
# 588               Gerber                                    —
# 627                Malin                 Club Rubiyat earlier
# 5703                   —                                    —
# 5704                   —                                    —
# 5706                   —                                    —
# 5723                   —                                    —
# 5736                   —                                    —
# 5737              Curtis                          [warehouse]
# 5788                   —                                    —
# 6213               Moore     Boy! What a Girl (film musical),
# 7266                   —                                    —
# 7796            Hamilton           (Canadian but toured U.S.)
# 7835               Jones  (in "The Name of the Game is Kill")
# 7879              Bailey                            Palladium
# 7881                   —                                    —
# 7882              Pierce                       Country Cousin
# 7883                   —                                    —
# 7902              Bailey                      Harrah's Marina
#
#                                     City Normalized City Revue name  ...  \
# 587                         New York, NY    New York, NY      Pansy  ...
# 588                         New York, NY    New York, NY      Pansy  ...
# 627                                    —               —             ...
# 5703                                   —               —             ...
# 5704                                   —               —             ...
# 5706                                   —               —             ...
# 5723                                   —               —             ...
# 5736                                   —               —             ...
# 5737  Richibucto, New Brunswick, Canada?               —             ...
# 5788                                   —               —             ...
# 6213                                   —               —             ...
# 7266                                   —               —             ...
# 7796                                   —               —  Dumbbells  ...
# 7835                                   —               —             ...
# 7879                              London               —             ...
# 7881                                   —               —             ...
# 7882                     Chelsea, London               —             ...
# 7883                                   —               —             ...
# 7902                   Atlantic City, NJ               —             ...
#
#      Search (fulton) Imported from former archive Edge Comment  \
# 587                      Connect New York project
# 588                      Connect New York project
# 627                          Queer Music Heritage
# 5703
# 5704
# 5706
# 5723
# 5736
# 5737                     Connect New York project
# 5788
# 6213                     Connect New York project
# 7266
# 7796                     Connect New York project
# 7835                     Connect New York project
# 7879                     Connect New York project
# 7881
# 7882                     Connect New York project
# 7883
# 7902                     Connect New York project
#
#      Exclude from visualization  \
# 587                        True
# 588                        True
# 627                        True
# 5703                       True
# 5704                       True
# 5706                       True
# 5723                       True
# 5736                       True
# 5737                       True
# 5788                       True
# 6213                       True
# 7266                       True
# 7796                       True
# 7835                       True
# 7879                       True
# 7881                       True
# 7882                       True
# 7883                       True
# 7902                       True
#
#                                       Quote from source  \
# 587
# 588
# 627
# 5703
# 5704
# 5706
# 5723  "Victor Mature says 'Footlight Serenade' will ...
# 5736
# 5737
# 5788
# 6213
# 7266
# 7796
# 7835
# 7879
# 7881
# 7882
# 7883
# 7902
#
#      Comment on node: performer Comment on node: venue Comment on node: city  \
# 587           Male impersonator
# 588           Male impersonator
# 627
# 5703
# 5704
# 5706
# 5723
# 5736
# 5737
# 5788
# 6213
# 7266
# 7796
# 7835
# 7879
# 7881
# 7882
# 7883
# 7902
#
#            Comment on edge: revue 2020-12-31 ID
# 587   [a new musical in New York]          4371
# 588   [a new musical in New York]          4370
# 627                                        4439
# 5703                                       6070
# 5704                                       6071
# 5706                                       6072
# 5723                                       6073
# 5736                                       6074
# 5737                                       4247
# 5788                                       6075
# 6213                                       4257
# 7266                                       6078
# 7796                                       4324
# 7835                                       4329
# 7879                                       4335
# 7881                                       6084
# 7882                                       4336
# 7883                                       6085
# 7902                                       4339
#
# [19 rows x 29 columns]

# %%
df2

# %%
df = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vT0E0Y7txIa2pfBuusA1cd8X5OVhQ_D0qZC8D40KhTU3xB7McsPR2kuB7GH6ncmNT3nfjEYGbscOPp0/pub?gid=0&single=true&output=csv')
df

# %%
df.drop(df[df['Exclude from visualization'] == True].index, inplace = True)

# %%
df
# Out:
#             Date Category Performer Normalized performer Performer first-name  \
# 0     1901-02-12                                       —                    —
# 1     1904-04-30                                       —                    —
# 2           1918                             Ray Francis                  Ray
# 5           1931                              Jean Malin                 Jean
# 6           1931                              Jean Malin                 Jean
# ...          ...      ...       ...                  ...                  ...
# 7990                                                   —                    —
# 7991                                                   —                    —
# 7992                                                   —                    —
# 7993                                                   —                    —
# 7994                                                   —                    —
#
#      Performer last-name          Venue              City   Normalized City  \
# 0                      —              —                 —                 —
# 1                      —              —                 —                 —
# 2                Francis  Lyric Theatre  Indianapolis, IN  Indianapolis, IN
# 5                  Malin  Club Argonaut      New York, NY      New York, NY
# 6                  Malin  Club Argonaut      New York, NY      New York, NY
# ...                  ...            ...               ...               ...
# 7990                   —              —                 —                 —
# 7991                   —              —                 —                 —
# 7992                   —              —                 —                 —
# 7993                   —              —                 —                 —
# 7994                   —              —                 —                 —
#
#      Revue name  ... Search (fulton) Imported from former archive  \
# 0                ...
# 1                ...
# 2                ...                         Queer Music Heritage
# 5                ...                         Queer Music Heritage
# 6                ...                         Queer Music Heritage
# ...         ...  ...             ...                          ...
# 7990             ...
# 7991             ...
# 7992             ...
# 7993             ...
# 7994             ...
#
#      Edge Comment Exclude from visualization Quote from source  \
# 0
# 1
# 2
# 5
# 6
# ...           ...                        ...               ...
# 7990
# 7991
# 7992
# 7993
# 7994
#
#      Comment on node: performer Comment on node: venue Comment on node: city  \
# 0
# 1
# 2
# 5
# 6
# ...                         ...                    ...                   ...
# 7990
# 7991
# 7992
# 7993
# 7994
#
#      Comment on edge: revue 2020-12-31 ID
# 0                                    6086
# 1                                    6087
# 2                                    4624
# 5                                    4444
# 6                                    4445
# ...                     ...           ...
# 7990
# 7991
# 7992
# 7993
# 7994
#
# [7971 rows x 29 columns]
